# %%
import time
import numpy as np
import pandas as pd

import galsim #install with conda install -c conda_forge galsim

import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.cm as cm
import matplotlib.colors as norm
from matplotlib.gridspec import SubplotSpec
import seaborn as sns

from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import cross_validate, KFold, StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.inspection import permutation_importance
from sklearn.pipeline import make_pipeline #This allows one to build different steps together
from sklearn.preprocessing import StandardScaler, RobustScaler

from tqdm import tqdm 

import target_predicting_RF_function_and_feature_ranking_TNGSIM as functions
import RF_target_predicting_and_learning_curves_functions_TNGSIM as tp_lc_functions

# %% [raw]
# import os
# os.mkdir('TNG-SIM_images/v13_Disks_SVR_RF')

# %%
# Using the 0D TNG100 SIM data at z=0 (version 3 of the dataset in this notebook, 
# which includes galaxies with log10Mstar=8 and MHI and MH2 are usable features)

df_0D = pd.read_csv('TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_0D_Dataset.csv')
df_raw = pd.read_csv('TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_Raw_Dataset.csv')
print("df_0D.shape", df_0D.shape)
print("df_raw.shape", df_raw.shape)
# Out:
# df_0D.shape (21598, 17)
# df_raw.shape (21598, 20)

# %% [markdown]
# ### <font color='purple'> <a id =10> </a> <br> Log scale of the mass, radius & SFR features

# %% [markdown]
# #### Log function

# %%
df_raw.shape
# Out:
# (21598, 20)

# %%
df_raw.loc[:,'SubhaloRstar_Log']=df_raw.loc[:,'SubhaloRstar'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'SubhaloRgas_Log']=df_raw.loc[:,'SubhaloRgas'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'SubhaloVmaxRad_Log']=np.log10(df_raw.loc[:,'SubhaloVmaxRad'])
df_raw.loc[:,'SubhaloVmax_Log']=np.log10(df_raw.loc[:,'SubhaloVmax'])    
df_raw.loc[:,'SubhaloVelDisp_Log']=np.log10(df_raw.loc[:,'SubhaloVelDisp'])

df_raw.loc[:,'SubhaloMgas_Log']=df_raw.loc[:,'SubhaloMgas'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'SubhaloMstar_Log']=df_raw.loc[:,'SubhaloMstar'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'SubhaloBHMass_Log']=df_raw.loc[:,'SubhaloBHMass'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'GroupBHMass_Log']=df_raw.loc[:,'GroupBHMass'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'SubhaloBHMdot_Log']=df_raw.loc[:,'SubhaloBHMdot'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'SubhaloMHI_Log']=df_raw.loc[:,'SubhaloMHI'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'SubhaloMH2_Log']=df_raw.loc[:,'SubhaloMH2'].apply(lambda x: np.log10(x) if x>0 else 0)

df_raw.loc[:,'Group_M_TopHat200_Log']=df_raw.loc[:,'Group_M_TopHat200'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'Group_R_TopHat200_Log']=df_raw.loc[:,'Group_R_TopHat200'].apply(lambda x: np.log10(x) if x>0 else 0)
df_raw.loc[:,'Group_V_TopHat200_Log']=df_raw.loc[:,'Group_V_TopHat200'].apply(lambda x: np.log10(x) if x>0 else 0)

# Set to -3.5 all SFR=0
df_raw.loc[:,'SubhaloSFRinRad_Log']=df_raw.loc[:,'SubhaloSFRinRad'].apply(lambda x: np.log10(x) if x>0 else -3.5)

# %%
df_raw.shape
# Out:
# (21598, 36)

# %%
df_lograw = df_raw.drop(columns=['SubhaloRstar', 'SubhaloRgas', 'SubhaloVmaxRad', 'SubhaloVmax','SubhaloVelDisp',
                                'SubhaloMgas', 'SubhaloMstar', 'SubhaloBHMass', 'GroupBHMass', 'SubhaloBHMdot',
                                'SubhaloMHI', 'SubhaloMH2',
                                'Group_M_TopHat200', 'Group_R_TopHat200', 'Group_V_TopHat200',
                                'SubhaloSFRinRad'])

# %%
df_lograw.shape
# Out:
# (21598, 20)

# %%
df_lograw.SubhaloSFRinRad_Log.mean()
# Out:
# -1.0705757341112732

# %%
df100_8_9 = df100_raw[df100_raw.SubhaloMstar_Log < 9.0]

# %%
df_lograw[df_lograw.SubhaloMstar_Log < 9.0].SubhaloSFRinRad_Log.mean()
# Out:
# -1.4009741589068665

# %%
df_lograw['class'] = pd.cut(df_lograw['SubhaloMstar_Log'], [8,9,10,10.5])

# %%
sns.lmplot(x = 'SubhaloMstar_Log', y = 'SubhaloSFRinRad_Log', data=df_lograw[df_lograw.SubhaloSFRinRad_Log>-3],
           fit_reg=True,
          markers='.')

# %%
sns.lmplot(x = 'SubhaloMstar_Log', y = 'SubhaloSFRinRad_Log', data=df_lograw[df_lograw.SubhaloSFRinRad_Log>-3],
           fit_reg=True, x_bins=[8,8.5,9, 9.5, 10, 10.5, 11, 11.5, 12],
          markers='o')

# %%
X = df_lograw.loc[:,'SubhaloMstar_Log'].values.reshape(-1,1)
y = df_lograw['SubhaloSFRinRad_Log'].values

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X, y)

# %%
df_lograw['prediction'] = reg.predict(X)

# %%
df_lograw[['prediction','SubhaloSFRinRad_Log']]
# Out:
#        prediction  SubhaloSFRinRad_Log
# 0       -0.064582            -0.708133
# 1       -0.120062             0.219496
# 2       -0.093086             0.184843
# 3       -0.188126             1.994171
# 4       -0.205759             0.236754
# ...           ...                  ...
# 21593   -1.317233            -3.500000
# 21594   -1.283465            -3.500000
# 21595   -1.311671            -3.500000
# 21596   -1.290646            -3.500000
# 21597   -1.323489            -3.500000
#
# [21598 rows x 2 columns]

# %%
df_lograw.loc[:,'SubhaloMstar_Log']

# %%
df_lograw1 = df_lograw[df_lograw.SubhaloSFRinRad_Log>-3]

# %%
X1 = df_lograw1.loc[:,'SubhaloMstar_Log'].values.reshape(-1,1)
y1 = df_lograw1['SubhaloSFRinRad_Log'].values

reg1 = LinearRegression().fit(X1, y1)

# %%
df_lograw1['prediction1'] = reg.predict(X1)
# Out:
# /var/folders/ln/75hwm53n5ml0l3lfft4tb7100000gn/T/ipykernel_60752/1656535721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lograw1['prediction1'] = reg.predict(X1)

# %%
# In this plot, all SFRinRad=0 values remain so after taking the Log of SFRinRad
fig1, ax5 = plt.subplots(nrows=1,ncols=1, figsize=(10,7))


im5 = ax5.scatter(df_lograw1.loc[:, 'SubhaloMstar_Log'], df_lograw1.loc[:, 'SubhaloSFRinRad_Log'],
                  s=3, marker='.', alpha=0.7
           )
im5 = ax5.plot(df_lograw1.loc[:, 'SubhaloMstar_Log'], df_lograw1['prediction1'], '-', color='orange', linewidth = 2)
# im5 = ax5.fill_between(sim100_mMstar, sim100_mSFR - sim100_stdSFR, sim100_mSFR + sim100_stdSFR,
#                  color='orange', alpha=0.5, label='TNG100 SIM std')
# ax5.set_xlim(auto=True)
# ax5.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax5.set_ylim(auto=True)
# ax5.axis([0.0,40, 0.0,40])
# ax5.plot([0.0, 40], [0.0, 40], color = 'black', linewidth = 2)
ax5.set_title(r'TNG100-SIM Central Galaxies Complete Raw Dataset')
ax5.set_xlabel(r'$log_{10}M_{star}$')
ax5.set_ylabel(r'$log_{10}SFR$')
ax5.legend(loc='lower right', shadow=True)

# cbar_ax = fig1.add_axes([0.91, 0.14, 0.02, 0.75])
# fig1.colorbar(im5, cax=cbar_ax, label=r'$log_{10}$Rstar')

fig1.subplots_adjust(top=0.9, hspace=2.0, wspace=0.03)
# fig1.tight_layout()
# fig1.savefig("TNG-SIM_images/v9_SFRvsMstar_50100300boxes/v9_TNG100-SIM_Raw_SFRvsMstar_SFRmean.jpeg", dpi=500)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# In this plot, all SFRinRad=0 values remain so after taking the Log of SFRinRad
fig1, ax5 = plt.subplots(nrows=1,ncols=1, figsize=(10,7))


im5 = ax5.scatter(df_lograw.loc[:, 'SubhaloMstar_Log'], df_lograw.loc[:, 'SubhaloSFRinRad_Log'],
                  s=3, marker='.', alpha=0.7
           )
im5 = ax5.plot(df_lograw.loc[:, 'SubhaloMstar_Log'], df_lograw['prediction'], '-', color='orange', linewidth = 2)
# im5 = ax5.fill_between(sim100_mMstar, sim100_mSFR - sim100_stdSFR, sim100_mSFR + sim100_stdSFR,
#                  color='orange', alpha=0.5, label='TNG100 SIM std')
# ax5.set_xlim(auto=True)
# ax5.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax5.set_ylim(auto=True)
# ax5.axis([0.0,40, 0.0,40])
# ax5.plot([0.0, 40], [0.0, 40], color = 'black', linewidth = 2)
ax5.set_title(r'TNG100-SIM Central Galaxies Complete Raw Dataset')
ax5.set_xlabel(r'$log_{10}M_{star}$')
ax5.set_ylabel(r'$log_{10}SFR$')
ax5.legend(loc='lower right', shadow=True)

# cbar_ax = fig1.add_axes([0.91, 0.14, 0.02, 0.75])
# fig1.colorbar(im5, cax=cbar_ax, label=r'$log_{10}$Rstar')

fig1.subplots_adjust(top=0.9, hspace=2.0, wspace=0.03)
# fig1.tight_layout()
# fig1.savefig("TNG-SIM_images/v9_SFRvsMstar_50100300boxes/v9_TNG100-SIM_Raw_SFRvsMstar_SFRmean.jpeg", dpi=500)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_lograw.groupby('class')['SubhaloSFRinRad_Log'].mean()
# Out:
# class
# (8.0, 9.0]     -1.400974
# (9.0, 10.0]    -0.617991
# (10.0, 10.5]   -1.213232
# Name: SubhaloSFRinRad_Log, dtype: float64

# %% [markdown]
# ### <font color='purple'> _____________________________________________________________________________________

# %% [markdown]
# ### <font color='purple'> <a id =2> </a> <br> SVR Complete log10 Raw Dataset

# %%
df_lograw.columns.to_list()
# Out:
# ['SubhaloGasMetallicity',
#  'SubhaloSFRinRad',
#  'SubhaloStarMetallicity',
#  'GroupNsubs',
#  'GroupSpin_dmo',
#  'SubhaloRstar_Log',
#  'SubhaloRgas_Log',
#  'SubhaloVmaxRad_Log',
#  'SubhaloVmax_Log',
#  'SubhaloVelDisp_Log',
#  'SubhaloMgas_Log',
#  'SubhaloMstar_Log',
#  'SubhaloBHMass_Log',
#  'GroupBHMass_Log',
#  'SubhaloBHMdot_Log',
#  'SubhaloMHI_Log',
#  'SubhaloMH2_Log',
#  'Group_M_TopHat200_Log',
#  'Group_R_TopHat200_Log',
#  'Group_V_TopHat200_Log']

# %% [markdown]
# Note that when using the 0D dataset, the SVR does not work. From our discussion w Vivi & Ari in Slack, the reason is explained below:
#
# In the 0D (normalized) dataset the range of the target variable becomes tiny. Since SVRs work by looking for a solution within a certain tolerance, when the values are very small that level of accuracy is reached quickly but it doesn't mean much. This is why the algorithm exits but still produces garbage. For the features this is not a problem because they are scaled before building a model, but the target isn't. The solution is to keep log(GalaxySize) as the target (the halo-unscaled varibale, but logged). With this change, the SVR do really well for both the raw and the dimensionless data [in the TNG300-SAM]
#
# The log solution is better than multiplying the target by 10^3 say, because the distribution of log sizes is much closer to a gaussian (in the TNG-SAM) than the galaxy size/halo size distribution. Hence, log sizes achieve a more stable solution with fewer iterations.
#
# In this notebook I use the unscaled features and logRstar as target.

# %%
X_all = df_lograw.drop(columns=['SubhaloRstar_Log'])
 

y_all = df_lograw.loc[:,'SubhaloRstar_Log']

# %%
# this code takes ~ ...min to run it on the complete TNG-SIM dataset with ~22,000 galaxies 

start_time = time.time()

piped_model = make_pipeline(StandardScaler(), SVR()) #non linear so I can change the kernel

piped_model.get_params() #this shows how we can access parameters both for the scaler and the classifier

#optimizing SVR

parameters = {'svr__kernel':['rbf'], \
              'svr__gamma':['scale', 0.001, 0.01, 1.0, 10, 100], 
              'svr__C':[0.1, 1.0, 10.0, 100.0, 1000], \
              }


model_all = GridSearchCV(piped_model, parameters, cv = KFold(n_splits=3, shuffle=True), \
                     verbose = 3, n_jobs = -1, return_train_score=True)

model_all.fit(X_all, y_all)

print('Best params, best score:', "{:.4f}".format(model_all.best_score_), \
      model_all.best_params_)

elapsed_time = time.time() - start_time
print(f"Elapsed time to compute the SVR results on TNG-SIM Log10 Raw Complete Dataset: {elapsed_time:.3f} seconds")
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV 3/3] END svr__C=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.823, test=0.818) total time=   2.4s
# [CV 2/3] END svr__C=0.1, svr__gamma=100, svr__kernel=rbf;, score=(train=0.411, test=-0.000) total time=  11.2s
# [CV 1/3] END svr__C=1.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.830, test=-0.008) total time=  24.8s
# [CV 2/3] END svr__C=10.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.828, test=-0.009) total time=  22.8s
# [CV 3/3] END svr__C=100.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.903, test=0.709) total time=   4.1s
# [CV 1/3] END svr__C=1000, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.921, test=0.854) total time= 1.6min
# [CV 1/3] END svr__C=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.695, test=0.700) total time=   3.9s
# [CV 1/3] END svr__C=1.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.901, test=0.876) total time=   1.7s
# [CV 3/3] END svr__C=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.812, test=0.802) total time=   2.6s
# [CV 2/3] END svr__C=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.718) total time=   3.3s
# [CV 2/3] END svr__C=10.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.915, test=0.888) total time=   3.9s
# [CV 1/3] END svr__C=10.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.893, test=0.882) total time=   2.9s
# [CV 3/3] END svr__C=10.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.905, test=0.712) total time=   4.1s
# [CV 2/3] END svr__C=100.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.921, test=0.877) total time=  15.7s
# [CV 1/3] END svr__C=100.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.906, test=0.887) total time=   8.3s
# [CV 3/3] END svr__C=100.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.833, test=-0.015) total time=  22.4s
# [CV 1/3] END svr__C=1000, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.702) total time=   3.7s
# [CV 3/3] END svr__C=1000, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.905, test=0.712) total time=   3.8s
# [CV 2/3] END svr__C=1000, svr__gamma=100, svr__kernel=rbf;, score=(train=0.830, test=-0.010) total time=  27.0s
# [CV 3/3] END svr__C=1000, svr__gamma=100, svr__kernel=rbf;, score=(train=0.833, test=-0.015) total time=  17.8s
# Best params, best score: 0.8884 {'svr__C': 100.0, 'svr__gamma': 0.01, 'svr__kernel': 'rbf'}
# Elapsed time to compute the SVR results on TNG-SIM Log10 Raw Complete Dataset: 172.654 seconds

# %% [markdown]
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
#
# Best params, best score: 0.8883 {'svr__C': 100.0, 'svr__gamma': 0.01, 'svr__kernel': 'rbf'}
# Elapsed time to compute the SVR results on TNG-SIM Log10 Raw Complete Dataset: 211.984 seconds ~ 3min

# %%
start_time = time.time()

best_SVR_all=model_all.best_estimator_

best_SVR_trainscore_all=model_all.cv_results_['mean_train_score'][model_all.best_index_]

scores_SVR_all = cross_val_score(best_SVR_all, X_all, y_all, cv = KFold(n_splits=5, shuffle=True, random_state=10)) # cv score in all data?

elapsed_time = time.time() - start_time
print(f"Elapsed time to compute this patch of code: {elapsed_time:.3f} seconds")

# It took 26.935 seconds ~ 1/2 min to run this patch of code
# Out:
# Elapsed time to compute this patch of code: 26.935 seconds
# [CV 2/3] END svr__C=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.766, test=0.637) total time=   3.0s
# [CV 3/3] END svr__C=0.1, svr__gamma=100, svr__kernel=rbf;, score=(train=0.406, test=0.000) total time=  11.4s
# [CV 3/3] END svr__C=1.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.829, test=-0.010) total time=  25.1s
# [CV 2/3] END svr__C=100.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.921, test=0.876) total time=  17.2s
# [CV 3/3] END svr__C=100.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.923, test=0.872) total time=  17.4s
# [CV 2/3] END svr__C=1000, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.920, test=0.855) total time= 1.5min
# [CV 2/3] END svr__C=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.819, test=0.824) total time=   2.6s
# [CV 1/3] END svr__C=0.1, svr__gamma=100, svr__kernel=rbf;, score=(train=0.412, test=-0.001) total time=   9.8s
# [CV 3/3] END svr__C=10.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.919, test=0.881) total time=   4.1s
# [CV 2/3] END svr__C=10.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.891, test=0.884) total time=   2.8s
# [CV 1/3] END svr__C=10.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.827, test=-0.005) total time=  21.8s
# [CV 2/3] END svr__C=100.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.903, test=0.718) total time=   3.8s
# [CV 1/3] END svr__C=1000, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.880, test=0.863) total time=  14.6s
# [CV 3/3] END svr__C=1000, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.883, test=0.869) total time=  15.1s
# [CV 2/3] END svr__C=1000, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.903, test=0.718) total time=   3.9s
# [CV 1/3] END svr__C=1000, svr__gamma=100, svr__kernel=rbf;, score=(train=0.827, test=-0.005) total time=  27.6s
# [CV 1/3] END svr__C=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.823, test=0.814) total time=   2.3s
# [CV 1/3] END svr__C=0.1, svr__gamma=100, svr__kernel=rbf;, score=(train=0.408, test=-0.000) total time=  11.4s
# [CV 3/3] END svr__C=1.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.835, test=0.069) total time=  22.9s
# [CV 1/3] END svr__C=10.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.830, test=-0.008) total time=  23.8s
# [CV 2/3] END svr__C=100.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.702) total time=   3.9s
# [CV 3/3] END svr__C=100.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.831, test=-0.011) total time=  25.0s
# [CV 2/3] END svr__C=1000, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.702) total time=   3.8s
# [CV 1/3] END svr__C=1000, svr__gamma=10, svr__kernel=rbf;, score=(train=0.837, test=0.073) total time=  21.3s
# [CV 3/3] END svr__C=1000, svr__gamma=10, svr__kernel=rbf;, score=(train=0.837, test=0.069) total time=  23.0s
# [CV 3/3] END svr__C=0.1, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.854, test=0.845) total time=   2.2s
# [CV 1/3] END svr__C=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.756, test=0.635) total time=   3.0s
# [CV 3/3] END svr__C=1.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.904, test=0.877) total time=   1.8s
# [CV 2/3] END svr__C=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.870, test=0.868) total time=   2.0s
# [CV 1/3] END svr__C=1.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.826, test=-0.004) total time=  21.4s
# [CV 3/3] END svr__C=100.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.924, test=0.867) total time=  15.4s
# [CV 3/3] END svr__C=100.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.905, test=0.712) total time=   3.8s
# [CV 2/3] END svr__C=1000, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.879, test=0.874) total time=  14.6s
# [CV 1/3] END svr__C=1000, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.914, test=0.882) total time= 1.0min
# [CV 1/3] END svr__C=0.1, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.854, test=0.845) total time=   1.9s
# [CV 3/3] END svr__C=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.759, test=0.653) total time=   3.4s
# [CV 2/3] END svr__C=1.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.901, test=0.880) total time=   2.1s
# [CV 1/3] END svr__C=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.871, test=0.864) total time=   2.1s
# [CV 3/3] END svr__C=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.875, test=0.864) total time=   2.0s
# [CV 2/3] END svr__C=1.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.834, test=0.072) total time=  21.6s
# [CV 3/3] END svr__C=10.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.903, test=0.709) total time=   4.0s
# [CV 1/3] END svr__C=100.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.922, test=0.874) total time=  18.9s
# [CV 1/3] END svr__C=100.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.906, test=0.883) total time=   9.9s
# [CV 3/3] END svr__C=100.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.837, test=0.069) total time=  22.5s
# [CV 2/3] END svr__C=1000, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.914, test=0.889) total time=  56.3s
# [CV 2/3] END svr__C=1000, svr__gamma=100, svr__kernel=rbf;, score=(train=0.828, test=-0.009) total time=  19.9s
# [CV 2/3] END svr__C=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.694, test=0.701) total time=   3.9s
# [CV 2/3] END svr__C=0.1, svr__gamma=100, svr__kernel=rbf;, score=(train=0.408, test=0.000) total time=   9.8s
# [CV 1/3] END svr__C=10.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.843, test=0.840) total time=   2.7s
# [CV 3/3] END svr__C=10.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.896, test=0.878) total time=   2.8s
# [CV 2/3] END svr__C=10.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.830, test=-0.010) total time=  21.5s
# [CV 1/3] END svr__C=100.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.827, test=-0.005) total time=  22.0s
# [CV 2/3] END svr__C=1000, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.914, test=0.889) total time= 1.0min
# [CV 2/3] END svr__C=0.1, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.851, test=0.839) total time=   2.0s
# [CV 2/3] END svr__C=0.1, svr__gamma=10, svr__kernel=rbf;, score=(train=0.437, test=0.055) total time=  10.5s
# [CV 2/3] END svr__C=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.702) total time=   3.3s
# [CV 1/3] END svr__C=10.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.916, test=0.882) total time=   4.6s
# [CV 3/3] END svr__C=10.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.918, test=0.885) total time=   5.3s
# [CV 3/3] END svr__C=10.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.896, test=0.883) total time=   3.3s
# [CV 2/3] END svr__C=10.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.702) total time=   3.8s
# [CV 3/3] END svr__C=10.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.837, test=0.069) total time=  21.6s
# [CV 1/3] END svr__C=100.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.904, test=0.724) total time=   4.0s
# [CV 1/3] END svr__C=100.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.837, test=0.073) total time=  21.7s
# [CV 1/3] END svr__C=1000, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.915, test=0.879) total time= 1.0min
# [CV 3/3] END svr__C=1000, svr__gamma=100, svr__kernel=rbf;, score=(train=0.831, test=-0.011) total time=  20.0s
# [CV 3/3] END svr__C=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.702, test=0.687) total time=   3.8s
# [CV 3/3] END svr__C=0.1, svr__gamma=100, svr__kernel=rbf;, score=(train=0.406, test=-0.000) total time=   9.8s
# [CV 2/3] END svr__C=10.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.840, test=0.845) total time=   2.7s
# [CV 1/3] END svr__C=10.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.702) total time=   3.5s
# [CV 3/3] END svr__C=10.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.833, test=-0.015) total time=  21.8s
# [CV 2/3] END svr__C=100.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.830, test=-0.010) total time=  22.1s
# [CV 3/3] END svr__C=1000, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.917, test=0.882) total time= 1.0min
# [CV 3/3] END svr__C=0.1, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.855, test=0.838) total time=   1.9s
# [CV 1/3] END svr__C=0.1, svr__gamma=10, svr__kernel=rbf;, score=(train=0.435, test=0.056) total time=  10.6s
# [CV 3/3] END svr__C=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.709) total time=   3.4s
# [CV 2/3] END svr__C=10.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.915, test=0.887) total time=   4.4s
# [CV 1/3] END svr__C=10.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.892, test=0.880) total time=   4.3s
# [CV 2/3] END svr__C=10.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.892, test=0.885) total time=   3.2s
# [CV 1/3] END svr__C=10.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.904, test=0.724) total time=   4.1s
# [CV 2/3] END svr__C=10.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.834, test=0.072) total time=  20.4s
# [CV 2/3] END svr__C=100.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.905, test=0.891) total time=   9.8s
# [CV 2/3] END svr__C=100.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.828, test=-0.009) total time=  24.3s
# [CV 3/3] END svr__C=1000, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.917, test=0.885) total time=  58.9s
# [CV 1/3] END svr__C=0.1, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.854, test=0.831) total time=   2.2s
# [CV 3/3] END svr__C=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.824, test=0.815) total time=   2.3s
# [CV 2/3] END svr__C=1.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.900, test=0.882) total time=   1.9s
# [CV 1/3] END svr__C=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.872, test=0.863) total time=   1.9s
# [CV 3/3] END svr__C=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.904, test=0.712) total time=   3.2s
# [CV 1/3] END svr__C=10.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.916, test=0.881) total time=   3.7s
# [CV 3/3] END svr__C=10.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.845, test=0.835) total time=   2.7s
# [CV 2/3] END svr__C=10.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.903, test=0.718) total time=   4.1s
# [CV 1/3] END svr__C=100.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.921, test=0.871) total time=  16.0s
# [CV 2/3] END svr__C=100.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.905, test=0.893) total time=   8.4s
# [CV 1/3] END svr__C=1000, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.920, test=0.846) total time= 1.5min
# [CV 1/3] END svr__C=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.760, test=0.664) total time=   3.1s
# [CV 1/3] END svr__C=1.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.901, test=0.877) total time=   2.4s
# [CV 3/3] END svr__C=1.0, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.904, test=0.879) total time=   2.1s
# [CV 2/3] END svr__C=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.869, test=0.866) total time=   2.0s
# [CV 1/3] END svr__C=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.904, test=0.724) total time=   3.3s
# [CV 2/3] END svr__C=1.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.827, test=-0.009) total time=  24.3s
# [CV 3/3] END svr__C=10.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.831, test=-0.011) total time=  24.0s
# [CV 2/3] END svr__C=100.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.834, test=0.072) total time=  21.2s
# [CV 3/3] END svr__C=1000, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.922, test=0.849) total time= 1.4min
# [CV 2/3] END svr__C=0.1, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.852, test=0.848) total time=   2.3s
# [CV 2/3] END svr__C=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.765, test=0.661) total time=   2.9s
# [CV 1/3] END svr__C=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.809, test=0.809) total time=   2.6s
# [CV 3/3] END svr__C=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.873, test=0.861) total time=   2.1s
# [CV 2/3] END svr__C=1.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.829, test=-0.010) total time=  21.4s
# [CV 1/3] END svr__C=100.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.864, test=0.856) total time=   4.3s
# [CV 3/3] END svr__C=100.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.865, test=0.854) total time=   4.3s
# [CV 1/3] END svr__C=100.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.902, test=0.702) total time=   3.7s
# [CV 3/3] END svr__C=1000, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.923, test=0.846) total time= 1.5min
# [CV 2/3] END svr__C=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.819, test=0.821) total time=   2.3s
# [CV 3/3] END svr__C=0.1, svr__gamma=10, svr__kernel=rbf;, score=(train=0.431, test=0.053) total time=  10.2s
# [CV 1/3] END svr__C=1.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.836, test=0.074) total time=  22.2s
# [CV 1/3] END svr__C=10.0, svr__gamma=10, svr__kernel=rbf;, score=(train=0.837, test=0.073) total time=  21.3s
# [CV 3/3] END svr__C=100.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.908, test=0.890) total time=   9.5s
# [CV 1/3] END svr__C=100.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.830, test=-0.008) total time=  25.0s
# [CV 1/3] END svr__C=1000, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.904, test=0.724) total time=   4.1s
# [CV 3/3] END svr__C=1000, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.903, test=0.709) total time=   4.0s
# [CV 2/3] END svr__C=1000, svr__gamma=10, svr__kernel=rbf;, score=(train=0.834, test=0.072) total time=  21.0s
# [CV 1/3] END svr__C=1000, svr__gamma=100, svr__kernel=rbf;, score=(train=0.830, test=-0.008) total time=  24.2s
# [CV 1/3] END svr__C=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.821, test=0.812) total time=   2.5s
# [CV 3/3] END svr__C=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.765, test=0.657) total time=   2.9s
# [CV 2/3] END svr__C=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.807, test=0.814) total time=   2.5s
# [CV 1/3] END svr__C=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.901, test=0.702) total time=   3.2s
# [CV 3/3] END svr__C=1.0, svr__gamma=100, svr__kernel=rbf;, score=(train=0.831, test=-0.015) total time=  21.4s
# [CV 2/3] END svr__C=100.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.862, test=0.859) total time=   4.6s
# [CV 3/3] END svr__C=100.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.909, test=0.886) total time=   8.3s
# [CV 2/3] END svr__C=1000, svr__gamma=scale, svr__kernel=rbf;, score=(train=0.921, test=0.853) total time= 1.5min

# %%
start_time = time.time()

y_pred_SVR_all = cross_val_predict(best_SVR_all, X_all, y_all, cv = KFold(n_splits=5, shuffle=True, random_state=10))

elapsed_time = time.time() - start_time
print(f"Elapsed time to compute the SVR y_pred with cv=5 and optimal model from above, on Raw Complete Dataset: {elapsed_time:.3f} seconds")

# It took 54 seconds ~ 1min to run this patch of code
# Out:
# Elapsed time to compute the SVR y_pred with cv=5 and optimal model from above, on Raw Complete Dataset: 26.763 seconds

# %%
# y_pred_SVR_df_all = pd.DataFrame({'y_pred_SVR SIM LogRaw': y_pred_SVR_all})

# y_pred_SVR_df_all.to_csv('TNG-SIM_images/v12_SVR/v12_TNG-SIM_Raw_AllDataset_y_pred_SVR_predicted_sizes.csv', index=False)

# y_pred_SVR_all = pd.read_csv('TNG-SIM_images/v12_SVR/v12_TNG-SIM_Raw_AllDataset_y_pred_SVR_predicted_sizes.csv')

# %% [markdown]
# ### <font color='purple'> <a id =2> </a> <br> SVR predictions vs True Rstar

# %%
label = 'Train score={} \n Test score={}'.format(round(best_SVR_trainscore_all, 2),round(scores_SVR_all.mean(), 2) )


plt.scatter(df_lograw.loc[:, 'SubhaloRstar_Log'], y_pred_SVR_all, s=3, marker='.', alpha=0.7, label=label,
                c = df_raw.loc[:, 'SubhaloVmaxRad'],cmap='Spectral', vmin=0.0, vmax=25)
# ax5.set_xlim(auto=True)
# ax5.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax5.set_ylim(auto=True)
plt.axis([-0.5,2.0, -0.5,2.0])
plt.plot([-0.5, 2.0], [-0.5, 2.0], color = 'black', linewidth = 2)
plt.title('TNG-SIM Central Galaxies LogRaw Features \n Complete Dataset, SVR Model')
plt.xlabel(r'True $log_{10}$Rstar')
plt.ylabel(r'Predicted $log_{10}$Rstar')
plt.legend(loc='lower right', shadow=True)
plt.colorbar(label=r'VmaxRad')

# plt.savefig("TNG-SIM_images/v12_SVR/v12_TNG-SIM_Raw_AllDataset_SVR_size_prediction_colorVmaxRad.jpeg", dpi=500)
plt.show()

# %% [markdown]
# ### <font color='purple'> <a id =3> </a> <br> SVR Learning Curve

# %%
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


def plot_learning_curve(estimator, title, X, y, ylim=None, cv=5,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5), scoring = 'r2', scale = False):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    
    fig, ax = plt.subplots(figsize=(7, 5))
#     plt.figure()
    ax.set_title(title)
    if ylim is not None:
        ax.set_ylim(*ylim)
    ax.set_xlabel("# of training examples",fontsize = 14)
 
    ax.set_ylabel("R2 score",fontsize = 14)
    
    if (scale == True):
        scaler = sklearn.preprocessing.StandardScaler()
        X = scaler.fit_transform(X)
    
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring = scoring)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
#    plt.grid()

    ax.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="b")
    ax.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    ax.plot(train_sizes, train_scores_mean, 'o-', color="b",
             label="Training score from CV")
    ax.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Test score from CV")

    ax.legend(loc="best",fontsize = 12)
    return fig

# %%
# this code takes ~2.5min to run on the whole dataset with ~22,000 galaxies
start_time = time.time()

lc_all = plot_learning_curve(best_SVR_all, 'SVR Learning Curve, Log Raw Complete Dataset', X_all, y_all, ylim=(0.0, 1.0), train_sizes = np.array([0.05,0.1,0.2,0.5,1.0]), scoring='r2', cv = KFold(n_splits=5, shuffle=True))
# plt.savefig('LC_SVR_Complete_Dataset.jpeg', dpi=500)
elapsed_time = time.time() - start_time

print(f"Elapsed time to run SVR Learning Curves on the Log Raw complete dataset: {elapsed_time:.3f} seconds")
# Out:
# Elapsed time to run SVR Learning Curves on the Log Raw complete dataset: 15.700 seconds

# %%
# lc_all.savefig('TNG-SIM_images/v12_SVR/v12_TNG-SIM_Raw_AllDataset_SVR_Learning_Curve.jpeg', dpi=500)

# %% [markdown]
# ### <font color='purple'> <a id =4> </a> <br> RF predicting log10(Rstar) using log10Raw dataset & its Learning Curve

# %%
# this code takes 2089.613 seconds ~ 35 min to run when the dataset is TNG100-SIM galaxies
# with ~22,000 entries
start_time = time.time()

RF_lc_2 = tp_lc_functions.target_predicting_RF_function(X_all, y_all, r'TNG-SIM RF Learnig Curve, Log Raw Complete Dataset \n log10(Rstar) ')

elapsed_time = time.time() - start_time

print(f"Elapsed time to run RF func and Learning Curves on TNG-SIM Log Raw Complete Dataset: {elapsed_time:.3f} seconds")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# /Users/festabu/miniforge3/envs/native/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best params, best score: 0.8720 {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 500}
# RF Accuracy: 0.87 (+/- 0.01)
# Elapsed time to compute the importances: 0.358 seconds
# Elapsed time to compute the importances: 128.197 seconds
# /Users/festabu/miniforge3/envs/native/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Elapsed time to run RF func and Learning Curves on TNG-SIM Log Raw Complete Dataset: 2089.613 seconds

# %%
y_pred_RF_df_all = RF_lc_2[0]
# y_pred_RF_df_all = pd.DataFrame({'y_pred_RF log10(Rstar) SIM LogRaw': y_pred_RF_df_all})

# y_pred_RF_df_all.to_csv('TNG-SIM_images/v12_SVR/v12_TNG-SIM_Raw_AllDataset_y_pred_RF_predicted_sizes.csv', index=False)

y_pred_RF_all = pd.read_csv('TNG-SIM_images/v12_SVR/v12_TNG-SIM_Raw_AllDataset_y_pred_RF_predicted_sizes.csv')

# %%
lc_2 = RF_lc_2[4]
# lc_2.savefig('TNG-SIM_images/v12_SVR/v12_TNG-SIM_Raw_AllDataset_RF_Learning_Curve_zoom.jpeg', dpi=500)

# %%
label = 'Train score=0.98 \n Test score=0.87'


plt.scatter(df_lograw.loc[:, 'SubhaloRstar_Log'], y_pred_RF_all, s=3, marker='.', alpha=0.7, label=label,
                c = df_raw.loc[:, 'SubhaloVmaxRad'],cmap='Spectral', vmin=0.0, vmax=25)
# ax5.set_xlim(auto=True)
# ax5.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax5.set_ylim(auto=True)
plt.axis([-0.5,2.0, -0.5,2.0])
plt.plot([-0.5, 2.0], [-0.5, 2.0], color = 'black', linewidth = 2)
plt.title('TNG-SIM Central Galaxies LogRaw Features \n Complete Dataset, RF Model')
plt.xlabel(r'True $log_{10}$Rstar')
plt.ylabel(r'Predicted $log_{10}$Rstar')
plt.legend(loc='lower right', shadow=True)
plt.colorbar(label=r'VmaxRad')

# plt.savefig("TNG-SIM_images/v12_SVR/v12_TNG-SIM_Raw_AllDataset_RF_size_prediction_colorVmaxRad.jpeg", dpi=500)
# plt.show()
