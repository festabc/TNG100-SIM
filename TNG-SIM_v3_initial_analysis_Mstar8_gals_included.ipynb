# %% [markdown]
# ### This code provides:
#
#     1) Downloading the raw TNG100 SIM data at z=0 (version 3 of the dataset in this notebook, which includes galaxies with log10Mstar=8 and MHI and MH2 are usable features)
#     2) Choosing only central galaxies
#     3) Removing the 14 galaxies with NaNs in their _dmo values
#     4) Calculating the percentage of 0s in each column (feature) and removing the features with mostly 0 entries
#     5) Comparing the histograms of features vs their _dmo version
#     6) Looking at correlations of the raw dataset
#     7) Normalizing the dataset by dividing all mass features by halo mass, galaxy size by halo size
#     8) Removing the not needed features, as well as features used for normalization from the Normalized Dataset
#     9) Saving the Raw dataset
#     10) Saving the Normalized Dataset, as well as its version after removing the 23 non-physical galaxies
#     11) Looking at correlations of the 0D (dimensionless/normalized) dataset
#     12) Plotting mass-size-spin relation for Raw Dataset
#     13) Plotting mass-size-spin relation for 0D Dataset

# %%
import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.cm as cm
import matplotlib.colors as norm
from matplotlib.gridspec import SubplotSpec
import seaborn as sns
from scipy import stats

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', 100)

# %% [raw]
# # import os
# # os.mkdir('TNG-SIM_images/v3_initial_analysis')

# %%
# read the dark matter-matched SIM dataset of 9/2/23 downloaded from Dropbox 

# It is called tng100-matchLHalo_v2.h5 because it used the LHalo matching algorithm, and v2 because Ari fixed
# any matching problems in the previous dataset. The histogram of spin_dmo for centrals looks fine.  
# Still there is ~5% of centrals in the sim who match to satellites in the dmo where Ari set the spin to 0.0.
# We can either not include those in analysis, or think harder about wha to do with them.

# Note: Cleaning the data is now going to be much harder then it was for the SAM. 
# That is because only 82% of galaxies have a dark matter only match, and some matches may be better than others. 
# So when is something an outlier? I don't know:)
# The catalog should have a repeated entry with a dmo for the matching property in the dark matter only run.
# This only applies to properties that make sense in both catalogs. Our main interest in the dark matter only catalog 
# is the GroupSpin_dmo because the GroupSpin from the hydro catalog includes the spin of the stars.  
# I think GroupSpin shouldn't be used in ML, I include it to compare to GroupSpin_dmo for our understanding. 
# It is not clear that any other dmo features are useful as they should all have high correlation with the hydro total mass, and if they don't then I worry about the match.
# Subhalo and Group are like Galprop and Haloprop for the SAM
df=pd.read_hdf('/Users/festabu/Desktop/ML_galaxy_size_project/Codes/TNG_Data_SAM_and_SIM/data/tng100-matchLHalo_v3.h5')

# %%
df
# Out:
#          SubhaloBHMass  SubhaloBHMdot  SubhaloGasMetallicity   SubhaloMass  \
# 0         9.956542e+09       0.000398               0.007718  3.903116e+14
# 1         1.782920e+09       0.000230               0.008247  5.208271e+13
# 2         2.521123e+09       0.001054               0.011213  1.098658e+13
# 3         4.888925e+08       0.000051               0.020788  4.817231e+12
# 4         7.420399e+08       0.000047               0.013132  4.621686e+12
# ...                ...            ...                    ...           ...
# 925463    0.000000e+00       0.000000               0.000000  6.986945e+09
# 931184    0.000000e+00       0.000000               0.000000  5.913835e+09
# 942269    0.000000e+00       0.000000               0.000000  5.635641e+09
# 945339    0.000000e+00       0.000000               0.000000  5.926746e+09
# 1057646   0.000000e+00       0.000000               0.000000  6.623844e+08
#
#          SubhaloSFRinRad  SubhaloStarMetallicity  SubhaloVelDisp  SubhaloVmax  \
# 0               0.195825                0.028622      603.875061   999.385132
# 1               0.088085                0.021265      333.893250   514.775879
# 2               5.294215                0.025407      297.577271   461.641266
# 3               2.142880                0.023964      159.561844   291.936554
# 4               0.283784                0.020044      168.744232   294.432983
# ...                  ...                     ...             ...          ...
# 925463          0.000000                0.007651       27.146893    54.506321
# 931184          0.000000                0.010493       28.520468    59.081474
# 942269          0.000000                0.009866       22.921013    50.962437
# 945339          0.000000                0.008199       25.622509    49.928978
# 1057646         0.000000                0.018362       14.901277    40.809204
#
#          SubhaloVmaxRad  SubhaloRgas  SubhaloRstar   SubhaloMgas  \
# 0            465.664864   891.066223     67.312584  1.236131e+13
# 1            534.375928   523.474487     24.165314  3.277196e+12
# 2            100.825992    70.518997     21.284046  1.219379e+11
# 3              3.278761   165.368149      9.275959  1.175942e+07
# 4             59.798929    81.432083     12.771088  4.665965e+10
# ...                 ...          ...           ...           ...
# 925463         3.933093     0.000000      4.197745  0.000000e+00
# 931184         2.980457     0.000000      2.867347  0.000000e+00
# 942269         3.033161     0.000000      3.620246  0.000000e+00
# 945339         3.991295     0.000000      3.968744  0.000000e+00
# 1057646        1.031306     0.000000      0.876292  0.000000e+00
#
#          SubhaloMstar     SubhaloJx     SubhaloJy     SubhaloJz  \
# 0        3.143714e+12  25565.121094  -5412.154297 -34774.015625
# 1        5.267424e+11  18177.472656 -18764.296875  20260.164062
# 2        5.263741e+11   3511.812744   9133.740234    784.299500
# 3        4.426219e+10   2858.906250  -1565.697754  -3908.470215
# 4        1.159663e+11   1614.306519   1771.974243  -3377.773193
# ...               ...           ...           ...           ...
# 925463   2.745615e+08    -14.469650     -5.315268      4.098857
# 931184   3.214156e+08      5.023608     -6.882937     -0.057875
# 942269   2.512916e+08     14.458583      1.275575      1.986885
# 945339   3.225450e+08     -3.036354    -12.290475     -1.783092
# 1057646  3.981526e+08      2.114993      4.879570    -18.350342
#
#          SubhaloCentral  GroupNsubs   GroupBHMass     GroupMass  \
# 0                     1       17185  3.604464e+10  5.522448e+14
# 1                     0       17185  3.604464e+10  5.522448e+14
# 2                     0       17185  3.604464e+10  5.522448e+14
# 3                     0       17185  3.604464e+10  5.522448e+14
# 4                     0       17185  3.604464e+10  5.522448e+14
# ...                 ...         ...           ...           ...
# 925463                1           1  0.000000e+00  7.696412e+09
# 931184                1           1  0.000000e+00  6.659745e+09
# 942269                1           1  0.000000e+00  6.281740e+09
# 945339                1           1  0.000000e+00  6.014950e+09
# 1057646               1           1  0.000000e+00  6.711893e+08
#
#          Group_M_Crit200  Group_M_TopHat200  Group_R_Crit200  \
# 0           3.625763e+14       4.435949e+14      1465.437988
# 1           3.625763e+14       4.435949e+14      1465.437988
# 2           3.625763e+14       4.435949e+14      1465.437988
# 3           3.625763e+14       4.435949e+14      1465.437988
# 4           3.625763e+14       4.435949e+14      1465.437988
# ...                  ...                ...              ...
# 925463      7.657354e+09       8.092290e+09        40.508286
# 931184      6.436872e+09       7.048120e+09        38.229462
# 942269      5.720889e+09       6.255539e+09        36.756042
# 945339      6.115589e+09       6.296427e+09        37.583172
# 1057646     6.699105e+08       6.725512e+08        17.981834
#
#          Group_R_TopHat200    SubhaloMHI    SubhaloMH2  SubhaloMass_dmo  \
# 0              1959.448853  1.153075e+10  1.105946e+10     4.086920e+14
# 1              1959.448853  1.135352e+10  4.910214e+09     4.676955e+13
# 2              1959.448853  5.529453e+10  3.228322e+10              NaN
# 3              1959.448853  2.222854e+10  1.196808e+10     5.371537e+12
# 4              1959.448853  3.209130e+10  8.777918e+09     5.380579e+12
# ...                    ...           ...           ...              ...
# 925463           51.582172  0.000000e+00  0.000000e+00     1.533159e+10
# 931184           49.259880  0.000000e+00  0.000000e+00     1.307319e+10
# 942269           47.341087  0.000000e+00  0.000000e+00     1.430040e+10
# 945339           47.444756  0.000000e+00  0.000000e+00              NaN
# 1057646          22.510447  0.000000e+00  0.000000e+00              NaN
#
#          SubhaloVelDisp_dmo  SubhaloVmax_dmo  SubhaloVmaxRad_dmo  \
# 0                635.132324       981.919495          519.949219
# 1                357.544403       542.061462          222.147768
# 2                       NaN              NaN                 NaN
# 3                164.704544       276.304749          114.007625
# 4                175.896332       303.004944           93.127500
# ...                     ...              ...                 ...
# 925463            33.283447        64.543488            5.553132
# 931184            35.896076        70.614082            4.757021
# 942269            34.503525        66.300270            6.030053
# 945339                  NaN              NaN                 NaN
# 1057646                 NaN              NaN                 NaN
#
#          SubhaloJx_dmo  SubhaloJy_dmo  SubhaloJz_dmo  SubhaloCentral_dmo  \
# 0         20518.474609    1294.048096  -41196.515625                 1.0
# 1         14759.326172  -14425.914062   15648.297852                 0.0
# 2                  NaN            NaN            NaN                 NaN
# 3          3174.506104    -265.736572   -3417.126465                 0.0
# 4          1387.800903    1714.996460   -3271.587158                 0.0
# ...                ...            ...            ...                 ...
# 925463      -20.013868      23.702608      -3.449827                 0.0
# 931184       17.189728       2.369545      17.471411                 0.0
# 942269        4.594969      -8.119236     -15.861740                 0.0
# 945339             NaN            NaN            NaN                 NaN
# 1057646            NaN            NaN            NaN                 NaN
#
#          GroupNsubs_dmo  GroupMass_dmo  Group_M_Crit200_dmo  \
# 0               24681.0   5.835940e+14         3.505198e+14
# 1               24681.0   5.835940e+14         3.505198e+14
# 2                   NaN            NaN                  NaN
# 3               24681.0   5.835940e+14         3.505198e+14
# 4               24681.0   5.835940e+14         3.505198e+14
# ...                 ...            ...                  ...
# 925463           3108.0   8.041655e+13         6.536413e+13
# 931184            439.0   1.711064e+13         1.541116e+13
# 942269           2996.0   7.691815e+13         5.444613e+13
# 945339              NaN            NaN                  NaN
# 1057646             NaN            NaN                  NaN
#
#          Group_M_TopHat200_dmo  Group_R_Crit200_dmo  Group_R_TopHat200_dmo  \
# 0                 4.375438e+14          1449.026489            1950.562622
# 1                 4.375438e+14          1449.026489            1950.562622
# 2                          NaN                  NaN                    NaN
# 3                 4.375438e+14          1449.026489            1950.562622
# 4                 4.375438e+14          1449.026489            1950.562622
# ...                        ...                  ...                    ...
# 925463            8.028313e+13           827.841431            1108.349976
# 931184            1.769942e+13           511.432312             669.586731
# 942269            6.837425e+13           778.910278            1050.589600
# 945339                     NaN                  NaN                    NaN
# 1057646                    NaN                  NaN                    NaN
#
#          Group_V_TopHat200  Group_V_Crit200  GroupSpin  Group_V_TopHat200_dmo  \
# 0               986.644165      1031.454834   0.015910             982.121096
# 1               986.644165      1031.454834   0.000000             982.121096
# 2               986.644165      1031.454834   0.000000                    NaN
# 3               986.644165      1031.454834   0.000000             982.121096
# 4               986.644165      1031.454834   0.000000             982.121096
# ...                    ...              ...        ...                    ...
# 925463           25.972881        28.510292   0.008419             558.094728
# 931184           24.804142        26.907452   0.004932             337.140071
# 942269           23.836773        25.870310   0.009180             529.010112
# 945339           23.888409        26.451887   0.007976                    NaN
# 1057646          11.334564        12.656849   0.052948                    NaN
#
#          Group_V_Crit200_dmo  GroupSpin_dmo
# 0                1019.887621       0.016995
# 1                1019.887621       0.000000
# 2                        NaN       0.000000
# 3                1019.887621       0.000000
# 4                1019.887621       0.000000
# ...                      ...            ...
# 925463            582.680394       0.000036
# 931184            359.963013       0.000077
# 942269            548.244187       0.000023
# 945339                   NaN            NaN
# 1057646                  NaN            NaN
#
# [36923 rows x 46 columns]

# %%
# 36,923 galaxies now that log10Mstar=8 galaxies are included (21,447 galaxies when cutoff was log10Mstar>=9)
df.shape
# Out:
# (36923, 46)

# %%
df['SubhaloCentral'].describe()
# Out:
# count    36923.000000
# mean         0.585732
# std          0.492602
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: SubhaloCentral, dtype: float64

# %%
df['SubhaloCentral'].value_counts()
# Out:
# 1    21627
# 0    15296
# Name: SubhaloCentral, dtype: int64

# %%
df['SubhaloCentral_dmo'].describe()
# Out:
# count    31553.000000
# mean         0.675847
# std          0.468065
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: SubhaloCentral_dmo, dtype: float64

# %%
df['SubhaloCentral_dmo'].value_counts()
# Out:
# 1.0    21325
# 0.0    10228
# Name: SubhaloCentral_dmo, dtype: int64

# %% [markdown]
# 21,627 central galaxies in SIM; 21,325 central galaxies in DMO
#
# 2162700/21325=98.6
#
# About ~2% of central galaxies in SIM are matched to satellites in DMO

# %% [markdown]
# ## Choose Central Galaxies only - 12,966 galaxies are centrals

# %%
# choose only central galaxies only; 12,966 galaxies are centrals
df = df[df.loc[:, 'SubhaloCentral'] == True]

# %% [markdown]
# ## Why NaNs in Group_R_TopHat200_dmo_0D and Group_R_Crit200_dmo_0D??

# %%
df['Group_R_TopHat200'].describe()
# Out:
# count    21627.000000
# mean       167.949142
# std         97.392570
# min         22.510447
# 25%        118.405445
# 50%        139.674377
# 75%        182.575531
# max       2021.319336
# Name: Group_R_TopHat200, dtype: float64

# %%
df['Group_R_TopHat200_dmo'].describe()
# Out:
# count    21598.000000
# mean       186.766273
# std        152.431562
# min         54.420059
# 25%        122.969616
# 50%        144.606339
# 75%        190.814411
# max       1986.413452
# Name: Group_R_TopHat200_dmo, dtype: float64

# %%
df['Group_R_TopHat200_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
df['Group_M_TopHat200'].replace(0, np.nan).isnull().sum()
# Out:
# 0

# %%
df['Group_M_TopHat200_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
df['Group_V_TopHat200'].replace(0, np.nan).isnull().sum()
# Out:
# 0

# %%
df['Group_V_TopHat200_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
df['Group_R_Crit200'].replace(0, np.nan).isnull().sum()
# Out:
# 0

# %%
df['Group_R_Crit200_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
df['Group_M_Crit200'].replace(0, np.nan).isnull().sum()
# Out:
# 0

# %%
df['Group_M_Crit200_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
df['Group_V_Crit200'].replace(0, np.nan).isnull().sum()
# Out:
# 0

# %%
df['Group_V_Crit200_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
df['SubhaloMass'].replace(0, np.nan).isnull().sum()
# Out:
# 0

# %%
df['SubhaloMass_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
df['GroupMass'].replace(0, np.nan).isnull().sum()
# Out:
# 0

# %%
df['GroupMass_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
df['GroupSpin_dmo'].replace(0, np.nan).isnull().sum()
# Out:
# 29

# %%
2900/21627
# Out:
# 0.13409164470338003

# %% [markdown]
# Note: No NaNs in Group_R_TopHat200, Group_M_TopHat200 and Group_M_TopHat200;
#
# but 29 NaNs in Group_R_TopHat200_dmo, Group_M_TopHat200_dmo and Group_V_TopHat200_dmo (out of 21,627 total galaxies).
#
# Similarly, no NaNs in 'Group_R,M,V_Crit200', but 29 NaNs in 'Group_R, M, V_Crit200_dmo'.
#
# Similarly, no NaNs in 'SubhaloMass' and 'GroupMass', but 29 NaNs in 'SubhaloMass_dmo' and 'GroupMass_dmo'.
#
# GroupSpin has no NaNs, GroupSpin_dmo has 29 NaNs.

# %%
# Such an object with NaNs in _dmo values has strange 0 values for many other fields like Mgas, Rgas
# Mstar is log10Mstar=8 (small mass)
df.loc[813831, :]
# Out:
# SubhaloBHMass             0.000000e+00
# SubhaloBHMdot             0.000000e+00
# SubhaloGasMetallicity     0.000000e+00
# SubhaloMass               1.651273e+10
# SubhaloSFRinRad           0.000000e+00
# SubhaloStarMetallicity    9.282972e-03
# SubhaloVelDisp            3.638013e+01
# SubhaloVmax               7.169190e+01
# SubhaloVmaxRad            5.003431e+00
# SubhaloRgas               0.000000e+00
# SubhaloRstar              3.394639e+00
# SubhaloMgas               0.000000e+00
# SubhaloMstar              9.078227e+08
# SubhaloJx                 1.009063e+00
# SubhaloJy                -2.103759e+01
# SubhaloJz                -1.109929e+01
# SubhaloCentral            1.000000e+00
# GroupNsubs                1.000000e+00
# GroupBHMass               0.000000e+00
# GroupMass                 1.735872e+10
# Group_M_Crit200           1.783246e+10
# Group_M_TopHat200         1.870979e+10
# Group_R_Crit200           5.369353e+01
# Group_R_TopHat200         6.820634e+01
# SubhaloMHI                0.000000e+00
# SubhaloMH2                0.000000e+00
# SubhaloMass_dmo                    NaN
# SubhaloVelDisp_dmo                 NaN
# SubhaloVmax_dmo                    NaN
# SubhaloVmaxRad_dmo                 NaN
# SubhaloJx_dmo                      NaN
# SubhaloJy_dmo                      NaN
# SubhaloJz_dmo                      NaN
# SubhaloCentral_dmo                 NaN
# GroupNsubs_dmo                     NaN
# GroupMass_dmo                      NaN
# Group_M_Crit200_dmo                NaN
# Group_M_TopHat200_dmo              NaN
# Group_R_Crit200_dmo                NaN
# Group_R_TopHat200_dmo              NaN
# Group_V_TopHat200         3.434443e+01
# Group_V_Crit200           3.779018e+01
# GroupSpin                 7.186477e-03
# Group_V_TopHat200_dmo              NaN
# Group_V_Crit200_dmo                NaN
# GroupSpin_dmo                      NaN
# Name: 813831, dtype: float64

# %%
(np.log10(df['SubhaloMstar'])).min()
# Out:
# 8.301045

# %%
(np.log10(df['SubhaloMstar'])).max()
# Out:
# 12.497443

# %%
plt.hist(np.log10(df['SubhaloMstar']))
plt.show()

# %%
# 9,884 galaxies with log10Mstar<9
df[np.log10(df.loc[:, 'SubhaloMstar'])<9]
# Out:
#          SubhaloBHMass  SubhaloBHMdot  SubhaloGasMetallicity   SubhaloMass  \
# 536698    1.950218e+06       0.000024               0.006286  3.389692e+11
# 552034    1.553263e+06       0.000005               0.009320  1.715525e+11
# 563831    4.040788e+06       0.000240               0.005207  2.844515e+11
# 568208    8.434052e+06       0.000274               0.019359  2.755694e+11
# 578124    1.306809e+06       0.000005               0.004344  1.441449e+11
# ...                ...            ...                    ...           ...
# 925463    0.000000e+00       0.000000               0.000000  6.986945e+09
# 931184    0.000000e+00       0.000000               0.000000  5.913835e+09
# 942269    0.000000e+00       0.000000               0.000000  5.635641e+09
# 945339    0.000000e+00       0.000000               0.000000  5.926746e+09
# 1057646   0.000000e+00       0.000000               0.000000  6.623844e+08
#
#          SubhaloSFRinRad  SubhaloStarMetallicity  SubhaloVelDisp  SubhaloVmax  \
# 536698          0.265222                0.005974       59.720810    98.096748
# 552034          0.305482                0.009440       52.141312   100.433922
# 563831          0.253336                0.006761       54.237003    97.630959
# 568208          0.256558                0.015562       56.402298   105.777428
# 578124          0.172144                0.004163       42.035061    80.811378
# ...                  ...                     ...             ...          ...
# 925463          0.000000                0.007651       27.146893    54.506321
# 931184          0.000000                0.010493       28.520468    59.081474
# 942269          0.000000                0.009866       22.921013    50.962437
# 945339          0.000000                0.008199       25.622509    49.928978
# 1057646         0.000000                0.018362       14.901277    40.809204
#
#          SubhaloVmaxRad  SubhaloRgas  SubhaloRstar   SubhaloMgas  \
# 536698        19.053717    86.873512      3.793778  4.305528e+09
# 552034        13.277858    18.306160      2.712046  4.926097e+09
# 563831        20.056412    79.501945      4.324774  6.398062e+09
# 568208         0.416853    64.918106      0.547738  8.471021e+07
# 578124        16.980800    56.916992      4.633777  3.650548e+09
# ...                 ...          ...           ...           ...
# 925463         3.933093     0.000000      4.197745  0.000000e+00
# 931184         2.980457     0.000000      2.867347  0.000000e+00
# 942269         3.033161     0.000000      3.620246  0.000000e+00
# 945339         3.991295     0.000000      3.968744  0.000000e+00
# 1057646        1.031306     0.000000      0.876292  0.000000e+00
#
#          SubhaloMstar    SubhaloJx   SubhaloJy   SubhaloJz  SubhaloCentral  \
# 536698    848658176.0  -604.792969  -26.877411  988.674438               1
# 552034    992023168.0   474.646912  117.813217  407.880524               1
# 563831    909437440.0  -696.863708  -17.881002  348.029236               1
# 568208    868222528.0  1402.758423  261.953857 -153.420197               1
# 578124    567220800.0   224.029007 -232.317551 -356.040833               1
# ...               ...          ...         ...         ...             ...
# 925463    274561536.0   -14.469650   -5.315268    4.098857               1
# 931184    321415648.0     5.023608   -6.882937   -0.057875               1
# 942269    251291600.0    14.458583    1.275575    1.986885               1
# 945339    322544992.0    -3.036354  -12.290475   -1.783092               1
# 1057646   398152608.0     2.114993    4.879570  -18.350342               1
#
#          GroupNsubs  GroupBHMass     GroupMass  Group_M_Crit200  \
# 536698           38   37868720.0  7.490017e+11     3.105082e+11
# 552034           39    5052499.5  5.986376e+11     1.632951e+11
# 563831           28    6780050.0  4.998077e+11     2.225876e+11
# 568208           28    9931785.0  4.588436e+11     2.341344e+11
# 578124           35    3499921.5  4.049844e+11     1.047491e+11
# ...             ...          ...           ...              ...
# 925463            1          0.0  7.696412e+09     7.657354e+09
# 931184            1          0.0  6.659745e+09     6.436872e+09
# 942269            1          0.0  6.281740e+09     5.720889e+09
# 945339            1          0.0  6.014950e+09     6.115589e+09
# 1057646           1          0.0  6.711893e+08     6.699105e+08
#
#          Group_M_TopHat200  Group_R_Crit200  Group_R_TopHat200    SubhaloMHI  \
# 536698        3.734693e+11       139.162003         185.028183  2.492607e+09
# 552034        2.108711e+11       112.329346         152.924103  4.421196e+09
# 563831        4.194439e+11       124.549164         192.327927  1.873599e+09
# 568208        2.753395e+11       126.665222         167.143097  6.283628e+08
# 578124        1.353062e+11        96.876228         131.900208  2.368411e+09
# ...                    ...              ...                ...           ...
# 925463        8.092290e+09        40.508286          51.582172  0.000000e+00
# 931184        7.048120e+09        38.229462          49.259880  0.000000e+00
# 942269        6.255539e+09        36.756042          47.341087  0.000000e+00
# 945339        6.296427e+09        37.583172          47.444756  0.000000e+00
# 1057646       6.725512e+08        17.981834          22.510447  0.000000e+00
#
#           SubhaloMH2  SubhaloMass_dmo  SubhaloVelDisp_dmo  SubhaloVmax_dmo  \
# 536698   396463840.0     3.021321e+11           63.736752       105.162804
# 552034   558009280.0     1.173178e+11           56.403404        93.553909
# 563831   348437056.0     2.938143e+11           53.632023        90.574104
# 568208   152489680.0     3.081147e+11           57.244984       103.743484
# 578124   258126656.0     1.412057e+11           41.054592        74.832924
# ...              ...              ...                 ...              ...
# 925463           0.0     1.533159e+10           33.283447        64.543488
# 931184           0.0     1.307319e+10           35.896076        70.614082
# 942269           0.0     1.430040e+10           34.503525        66.300270
# 945339           0.0              NaN                 NaN              NaN
# 1057646          0.0              NaN                 NaN              NaN
#
#          SubhaloVmaxRad_dmo  SubhaloJx_dmo  SubhaloJy_dmo  SubhaloJz_dmo  \
# 536698            32.964782    -744.394043     302.593872     961.942139
# 552034            24.299226     364.462952     -24.497192     121.281464
# 563831            32.207711    -806.509949      47.859192     416.557312
# 568208            30.592604    1431.711792     744.343079    -404.714325
# 578124            20.432512     -31.014370    -108.813828    -579.743713
# ...                     ...            ...            ...            ...
# 925463             5.553132     -20.013868      23.702608      -3.449827
# 931184             4.757021      17.189728       2.369545      17.471411
# 942269             6.030053       4.594969      -8.119236     -15.861740
# 945339                  NaN            NaN            NaN            NaN
# 1057646                 NaN            NaN            NaN            NaN
#
#          SubhaloCentral_dmo  GroupNsubs_dmo  GroupMass_dmo  \
# 536698                  0.0            57.0   8.175598e+11
# 552034                  0.0            96.0   1.258222e+12
# 563831                  1.0            41.0   5.276232e+11
# 568208                  1.0            36.0   5.096583e+11
# 578124                  1.0            49.0   4.563172e+11
# ...                     ...             ...            ...
# 925463                  0.0          3108.0   8.041655e+13
# 931184                  0.0           439.0   1.711064e+13
# 942269                  0.0          2996.0   7.691815e+13
# 945339                  NaN             NaN            NaN
# 1057646                 NaN             NaN            NaN
#
#          Group_M_Crit200_dmo  Group_M_TopHat200_dmo  Group_R_Crit200_dmo  \
# 536698          2.973766e+11           3.975816e+11           137.170944
# 552034          4.766599e+11           5.670558e+11           160.533905
# 563831          2.194829e+11           3.961925e+11           123.967354
# 568208          2.342606e+11           2.816956e+11           126.692154
# 578124          1.026168e+11           1.346436e+11            96.215744
# ...                      ...                    ...                  ...
# 925463          6.536413e+13           8.028313e+13           827.841431
# 931184          1.541116e+13           1.769942e+13           511.432312
# 942269          5.444613e+13           6.837425e+13           778.910278
# 945339                   NaN                    NaN                  NaN
# 1057646                  NaN                    NaN                  NaN
#
#          Group_R_TopHat200_dmo  Group_V_TopHat200  Group_V_Crit200  GroupSpin  \
# 536698              188.926178          93.162857        97.951355   0.047555
# 552034              212.660568          77.002495        79.063171   0.038240
# 563831              188.701019          96.838936        87.662590   0.029581
# 568208              168.424408          84.163589        89.153442   0.072143
# 578124              131.683289          66.415634        68.186882   0.038789
# ...                        ...                ...              ...        ...
# 925463             1108.349976          25.972881        28.510292   0.008419
# 931184              669.586731          24.804142        26.907452   0.004932
# 942269             1050.589600          23.836773        25.870310   0.009180
# 945339                     NaN          23.888409        26.451887   0.007976
# 1057646                    NaN          11.334564        12.656849   0.052948
#
#          Group_V_TopHat200_dmo  Group_V_Crit200_dmo  GroupSpin_dmo
# 536698               95.126457            96.550959       0.049315
# 552034              107.078837           112.993941       0.011952
# 563831               95.016760            87.253115       0.035849
# 568208               84.805058            89.167992       0.082359
# 578124               66.307358            67.720550       0.047835
# ...                        ...                  ...            ...
# 925463              558.094728           582.680394       0.000036
# 931184              337.140071           359.963013       0.000077
# 942269              529.010112           548.244187       0.000023
# 945339                     NaN                  NaN            NaN
# 1057646                    NaN                  NaN            NaN
#
# [9884 rows x 46 columns]

# %%
df[df.loc[:, 'GroupSpin_dmo'].isna()].shape
# Out:
# (29, 46)

# %%
df_wNaNs = df[df.loc[:, 'GroupSpin_dmo'].isna()]

# %%
# drop the 29 rows that have NaNs in 'GroupSin_dmo'
df = df.dropna(axis=0,subset= ['GroupSpin_dmo'])

# Can also use the line below to get the same dataset
# df.dropna(axis=0,subset= ['GroupSpin_dmo'], inplace=True)

# %%
df
# Out:
#         SubhaloBHMass  SubhaloBHMdot  SubhaloGasMetallicity   SubhaloMass  \
# 0        9.956542e+09       0.000398               0.007718  3.903116e+14
# 17185    7.911793e+09       0.000097               0.004368  3.901083e+14
# 31342    1.190802e+10       0.000372               0.005708  3.297064e+14
# 41582    4.446824e+09       0.001083               0.014258  1.954304e+14
# 52618    3.605885e+09       0.000852               0.004526  2.200745e+14
# ...               ...            ...                    ...           ...
# 901833   0.000000e+00       0.000000               0.000000  1.049166e+10
# 916946   0.000000e+00       0.000000               0.000000  6.872328e+09
# 925463   0.000000e+00       0.000000               0.000000  6.986945e+09
# 931184   0.000000e+00       0.000000               0.000000  5.913835e+09
# 942269   0.000000e+00       0.000000               0.000000  5.635641e+09
#
#         SubhaloSFRinRad  SubhaloStarMetallicity  SubhaloVelDisp  SubhaloVmax  \
# 0              0.195825                0.028622      603.875061   999.385132
# 17185          1.657662                0.020940      594.971252   959.352661
# 31342          1.530534                0.022085      567.029297   983.835571
# 41582         98.666870                0.023172      468.810730   840.229553
# 52618          1.724860                0.021753      498.997559   809.679321
# ...                 ...                     ...             ...          ...
# 901833         0.000000                0.006870       29.541777    57.073399
# 916946         0.000000                0.011401       27.836445    59.340427
# 925463         0.000000                0.007651       27.146893    54.506321
# 931184         0.000000                0.010493       28.520468    59.081474
# 942269         0.000000                0.009866       22.921013    50.962437
#
#         SubhaloVmaxRad  SubhaloRgas  SubhaloRstar   SubhaloMgas  SubhaloMstar  \
# 0           465.664864   891.066223     67.312584  1.236131e+13  3.143714e+12
# 17185      1364.142938   974.030151    125.480888  4.078112e+13  2.074321e+12
# 31342       880.071813   763.659424     82.916382  2.839754e+13  2.539053e+12
# 41582       419.666637   609.062561     28.387566  9.348383e+12  1.245521e+12
# 52618       987.573364   719.849976     50.823353  2.484471e+13  1.091353e+12
# ...                ...          ...           ...           ...           ...
# 901833        4.682093     0.000000      3.610430  0.000000e+00  2.633523e+08
# 916946        2.572634     0.000000      3.105893  0.000000e+00  3.391862e+08
# 925463        3.933093     0.000000      4.197745  0.000000e+00  2.745615e+08
# 931184        2.980457     0.000000      2.867347  0.000000e+00  3.214156e+08
# 942269        3.033161     0.000000      3.620246  0.000000e+00  2.512916e+08
#
#            SubhaloJx     SubhaloJy     SubhaloJz  SubhaloCentral  GroupNsubs  \
# 0       25565.121094  -5412.154297 -34774.015625               1       17185
# 17185    5753.153809 -25815.882812 -28110.193359               1       14157
# 31342   17153.453125  -9344.583984 -82888.539062               1       10240
# 41582   -2540.343994 -23471.136719  25919.474609               1       11036
# 52618    1604.596558 -50761.707031  74611.609375               1        8113
# ...              ...           ...           ...             ...         ...
# 901833     -3.212281      4.245679     -7.724226               1           1
# 916946      2.371075      3.358664     -9.814456               1           1
# 925463    -14.469650     -5.315268      4.098857               1           1
# 931184      5.023608     -6.882937     -0.057875               1           1
# 942269     14.458583      1.275575      1.986885               1           1
#
#          GroupBHMass     GroupMass  Group_M_Crit200  Group_M_TopHat200  \
# 0       3.604464e+10  5.522448e+14     3.625763e+14       4.435949e+14
# 17185   2.687727e+10  4.713209e+14     3.667457e+14       4.869390e+14
# 31342   2.595396e+10  3.795465e+14     3.247846e+14       3.869459e+14
# 41582   2.366535e+10  3.682170e+14     1.645434e+14       2.052039e+14
# 52618   1.525899e+10  2.805612e+14     2.441746e+14       2.930250e+14
# ...              ...           ...              ...                ...
# 901833  0.000000e+00  1.091274e+10     1.089233e+10       1.144587e+10
# 916946  0.000000e+00  6.999175e+09     6.951248e+09       7.252348e+09
# 925463  0.000000e+00  7.696412e+09     7.657354e+09       8.092290e+09
# 931184  0.000000e+00  6.659745e+09     6.436872e+09       7.048120e+09
# 942269  0.000000e+00  6.281740e+09     5.720889e+09       6.255539e+09
#
#         Group_R_Crit200  Group_R_TopHat200    SubhaloMHI    SubhaloMH2  \
# 0           1465.437988        1959.448853  1.153075e+10  1.105946e+10
# 17185       1471.055298        2021.319336  7.938982e+09  9.032034e+09
# 31342       1412.607422        1872.237793  4.318117e+09  4.893413e+09
# 41582       1126.165161        1515.466309  1.897611e+10  6.894150e+10
# 52618       1284.516602        1706.509644  8.968246e+09  1.303046e+10
# ...                 ...                ...           ...           ...
# 901833        45.554394          57.903389  0.000000e+00  0.000000e+00
# 916946        39.220924          49.733822  0.000000e+00  0.000000e+00
# 925463        40.508286          51.582172  0.000000e+00  0.000000e+00
# 931184        38.229462          49.259880  0.000000e+00  0.000000e+00
# 942269        36.756042          47.341087  0.000000e+00  0.000000e+00
#
#         SubhaloMass_dmo  SubhaloVelDisp_dmo  SubhaloVmax_dmo  \
# 0          4.086920e+14          635.132324       981.919495
# 17185      3.872118e+14          625.554626       915.306152
# 31342      3.320254e+14          594.152649       963.913086
# 41582      2.007685e+14          490.611969       826.877075
# 52618      2.171489e+14          526.401306       792.145935
# ...                 ...                 ...              ...
# 901833     1.737694e+10           35.115726        67.265320
# 916946     1.548499e+10           34.802910        70.209656
# 925463     1.533159e+10           33.283447        64.543488
# 931184     1.307319e+10           35.896076        70.614082
# 942269     1.430040e+10           34.503525        66.300270
#
#         SubhaloVmaxRad_dmo  SubhaloJx_dmo  SubhaloJy_dmo  SubhaloJz_dmo  \
# 0               519.949219   20518.474609    1294.048096  -41196.515625
# 17185          1388.533679    3450.526123  -24000.931641  -26503.224609
# 31342           819.257823   16126.270508   -2553.884277  -78882.312500
# 41582           445.759470  -12293.510742  -30651.265625   26668.580078
# 52618          1014.007395    4235.329590  -42084.218750   65089.945312
# ...                    ...            ...            ...            ...
# 901833            7.284349      -1.282621       6.027518     -20.688171
# 916946            4.856606       9.805397      16.916029     -21.759432
# 925463            5.553132     -20.013868      23.702608      -3.449827
# 931184            4.757021      17.189728       2.369545      17.471411
# 942269            6.030053       4.594969      -8.119236     -15.861740
#
#         SubhaloCentral_dmo  GroupNsubs_dmo  GroupMass_dmo  \
# 0                      1.0         24681.0   5.835940e+14
# 17185                  1.0         19381.0   4.919803e+14
# 31342                  1.0         14812.0   3.944735e+14
# 41582                  1.0         15339.0   3.840872e+14
# 52618                  1.0         11085.0   2.902799e+14
# ...                    ...             ...            ...
# 901833                 0.0           946.0   2.322469e+13
# 916946                 1.0             2.0   2.328288e+10
# 925463                 0.0          3108.0   8.041655e+13
# 931184                 0.0           439.0   1.711064e+13
# 942269                 0.0          2996.0   7.691815e+13
#
#         Group_M_Crit200_dmo  Group_M_TopHat200_dmo  Group_R_Crit200_dmo  \
# 0              3.505198e+14           4.375438e+14          1449.026489
# 17185          3.363435e+14           4.621193e+14          1429.226929
# 31342          3.134071e+14           3.839523e+14          1395.976807
# 41582          1.579129e+14           1.986131e+14          1110.797485
# 52618          2.446424e+14           2.913280e+14          1285.352051
# ...                     ...                    ...                  ...
# 901833         1.731329e+13           2.131539e+13           531.648926
# 916946         1.551056e+10           1.663550e+10            51.250938
# 925463         6.536413e+13           8.028313e+13           827.841431
# 931184         1.541116e+13           1.769942e+13           511.432312
# 942269         5.444613e+13           6.837425e+13           778.910278
#
#         Group_R_TopHat200_dmo  Group_V_TopHat200  Group_V_Crit200  GroupSpin  \
# 0                 1950.562622         986.644165      1031.454834   0.015910
# 17185             1986.413452        1017.780334      1035.385864   0.013266
# 31342             1867.351074         942.711609       994.308533   0.034117
# 41582             1499.048462         763.051514       792.635376   0.021438
# 52618             1703.192749         859.275024       904.096069   0.043523
# ...                       ...                ...              ...        ...
# 901833             712.381348          29.154572        32.064873   0.003929
# 916946              65.586479          25.040766        27.606205   0.006042
# 925463            1108.349976          25.972881        28.510292   0.008419
# 931184             669.586731          24.804142        26.907452   0.004932
# 942269            1050.589600          23.836773        25.870310   0.009180
#
#         Group_V_TopHat200_dmo  Group_V_Crit200_dmo  GroupSpin_dmo
# 0                  982.121096          1019.887621       0.016995
# 17185             1000.176016          1005.947150       0.012785
# 31342              940.285789           982.538398       0.032441
# 41582              754.797352           781.853979       0.026528
# 52618              857.617170           904.667544       0.037578
# ...                       ...                  ...            ...
# 901833             358.694438           374.206745       0.000060
# 916946              33.025167            36.074229       0.009550
# 925463             558.094728           582.680394       0.000036
# 931184             337.140071           359.963013       0.000077
# 942269             529.010112           548.244187       0.000023
#
# [21598 rows x 46 columns]

# %%
df_wNaNs['SubhaloMstar'].describe()
# Out:
# count    2.900000e+01
# mean     3.825035e+09
# std      8.628484e+09
# min      2.148894e+08
# 25%      3.981526e+08
# 50%      7.751219e+08
# 75%      1.538653e+09
# max      3.816403e+10
# Name: SubhaloMstar, dtype: float64

# %%
plt.hist(np.log10(df_wNaNs['SubhaloMstar']), bins=10, range=(8.0,10.5))
plt.title('SubhaloMstar of 29 gals with NaNs in _dmo')
plt.show()

# %%
# np.log10(df['SubhaloMstar']).min()=8.3
# np.log10(df['SubhaloMstar']).max()=12.49
plt.hist(np.log10(df['SubhaloMstar']), bins=200, range=(8.0,12.5))
plt.title('SubhaloMstar')
plt.show()

# %% [markdown]
# ### Conclusion: There is ~0.1% of data missing (NaNs) in the _dmo values, and I removed them from the dataset.
# ### Therefore, we have 21,598  central galaxies.

# %% [markdown]
# ## Compare GroupSpin & GroupNsubs vs their _dmo versions

# %%
plt.hist(df.loc[:, 'GroupSpin_dmo'], alpha=0.7, 
         color='darkorange', bins=200, label='GroupSpin_dmo', range=(0, 0.14))
plt.hist(df.loc[:, 'GroupSpin'], alpha=0.5, 
         color='blue', bins=200, label='GroupSpin', range=(0, 0.14))
plt.title('TNG100-SIM Spin Histogram of \n v3 Dataset')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Spin_histogram_v3_dataset.jpeg', dpi=500)
plt.show()

# %%
df.loc[:, 'GroupSpin_dmo'].describe()
# Out:
# count    21598.000000
# mean         0.031701
# std          0.018680
# min          0.000005
# 25%          0.018162
# 50%          0.028238
# 75%          0.041661
# max          0.141155
# Name: GroupSpin_dmo, dtype: float64

# %%
# 261 galaxies with almost 0 spin values
df[df.loc[:, 'GroupSpin_dmo']<0.001].shape
# Out:
# (261, 46)

# %%
plt.hist(df.loc[:, 'GroupNsubs_dmo'], alpha=0.7, 
         color='darkorange', bins=200, label='GroupNsubs_dmo', range=(0, 500))
plt.hist(df.loc[:, 'GroupNsubs'], alpha=0.5, 
         color='blue', bins=200, label='GroupNsubs', range=(0, 500))
plt.title('TNG100-SIM GroupNsubs Histogram of \n v3 Dataset')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_GroupNsubs_histogram_v3_dataset.jpeg', dpi=500)
plt.show()

# %%
# drop all the J columns bec not needed to feed to ML model
# SubhaloCentral is True if the subhalo is a central, so we want to take only True for now (only central gals)
# GroupNsubs are the number of subhalos in the Group (that is, number of galaxies in a halo)

df = df.drop(columns=['SubhaloJx', 'SubhaloJy', 'SubhaloJz', 
                 'SubhaloJx_dmo', 'SubhaloJy_dmo', 'SubhaloJz_dmo'])

# %%
df.shape
# Out:
# (21598, 40)

# %% [markdown]
# ## Calculate the percentage of zeros each columns has

# %%
# 1) replace 0s with NaN 2) .isnull() gives boolean (whether NaN is true or false)
# 3) .sum() sums the true instances (that is, all 0s in a column)
# 4) dividing by shape[0] divides by the number of total entries (12,966) 5) *100 to convert to percentages
100*df.replace(0, np.nan).isnull().sum()/df.shape[0]
# Out:
# SubhaloBHMass             5.250486
# SubhaloBHMdot             5.250486
# SubhaloGasMetallicity     2.453931
# SubhaloMass               0.000000
# SubhaloSFRinRad           7.940550
# SubhaloStarMetallicity    0.000000
# SubhaloVelDisp            0.000000
# SubhaloVmax               0.000000
# SubhaloVmaxRad            0.000000
# SubhaloRgas               2.185388
# SubhaloRstar              0.000000
# SubhaloMgas               3.787388
# SubhaloMstar              0.000000
# SubhaloCentral            0.000000
# GroupNsubs                0.000000
# GroupBHMass               4.968053
# GroupMass                 0.000000
# Group_M_Crit200           0.000000
# Group_M_TopHat200         0.000000
# Group_R_Crit200           0.000000
# Group_R_TopHat200         0.000000
# SubhaloMHI                2.171497
# SubhaloMH2                2.171497
# SubhaloMass_dmo           0.000000
# SubhaloVelDisp_dmo        0.000000
# SubhaloVmax_dmo           0.000000
# SubhaloVmaxRad_dmo        0.000000
# SubhaloCentral_dmo        3.245671
# GroupNsubs_dmo            0.000000
# GroupMass_dmo             0.000000
# Group_M_Crit200_dmo       0.000000
# Group_M_TopHat200_dmo     0.000000
# Group_R_Crit200_dmo       0.000000
# Group_R_TopHat200_dmo     0.000000
# Group_V_TopHat200         0.000000
# Group_V_Crit200           0.000000
# GroupSpin                 0.000000
# Group_V_TopHat200_dmo     0.000000
# Group_V_Crit200_dmo       0.000000
# GroupSpin_dmo             0.000000
# dtype: float64

# %%
# calculate the percentage of 0s in each column in order to 1) remove columns of all 0s;
# 2) decide what strategy to use for columns with mostly 0s
df_percentage=pd.DataFrame(100*df.replace(0, np.nan).isnull().sum()/df.shape[0] )

# %%
df_percentage
# Out:
#                                0
# SubhaloBHMass           5.250486
# SubhaloBHMdot           5.250486
# SubhaloGasMetallicity   2.453931
# SubhaloMass             0.000000
# SubhaloSFRinRad         7.940550
# SubhaloStarMetallicity  0.000000
# SubhaloVelDisp          0.000000
# SubhaloVmax             0.000000
# SubhaloVmaxRad          0.000000
# SubhaloRgas             2.185388
# SubhaloRstar            0.000000
# SubhaloMgas             3.787388
# SubhaloMstar            0.000000
# SubhaloCentral          0.000000
# GroupNsubs              0.000000
# GroupBHMass             4.968053
# GroupMass               0.000000
# Group_M_Crit200         0.000000
# Group_M_TopHat200       0.000000
# Group_R_Crit200         0.000000
# Group_R_TopHat200       0.000000
# SubhaloMHI              2.171497
# SubhaloMH2              2.171497
# SubhaloMass_dmo         0.000000
# SubhaloVelDisp_dmo      0.000000
# SubhaloVmax_dmo         0.000000
# SubhaloVmaxRad_dmo      0.000000
# SubhaloCentral_dmo      3.245671
# GroupNsubs_dmo          0.000000
# GroupMass_dmo           0.000000
# Group_M_Crit200_dmo     0.000000
# Group_M_TopHat200_dmo   0.000000
# Group_R_Crit200_dmo     0.000000
# Group_R_TopHat200_dmo   0.000000
# Group_V_TopHat200       0.000000
# Group_V_Crit200         0.000000
# GroupSpin               0.000000
# Group_V_TopHat200_dmo   0.000000
# Group_V_Crit200_dmo     0.000000
# GroupSpin_dmo           0.000000

# %%
# 2% of MHI and MH2 (469 galaxies) are 0s
plt.hist((df.loc[:,'SubhaloMHI'].apply(lambda x: np.log10(x) if x>0 else 0)), bins=200)
plt.show()

# %%
plt.hist((df.loc[:,'SubhaloMH2'].apply(lambda x: np.log10(x) if x>0 else 0)), bins=200)
plt.show()

# %%
df['SubhaloMH2'].replace(0, np.nan).isnull().sum()
# Out:
# 469

# %%
df['SubhaloMHI'].replace(0, np.nan).isnull().sum()
# Out:
# 469

# %%
# Save the df with the percentage of 0s of each column
# df_percentage.to_csv('TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_percentage_of_0s_per_column.csv', index=True)

# %% [markdown]
# ### SubhaloMass & GroupMass vs their _dmo values

# %%
plt.hist(np.log10(df['SubhaloMass']), bins=200, range=(8,14),
        label='SubhaloMass')
plt.hist(np.log10(df['SubhaloMstar']), bins=200, range=(8,14),
        label='SubhaloMstar', alpha=0.7)
plt.legend()
plt.show()

# %%
plt.hist(np.log10(df['SubhaloMass']), bins=200, range=(9.5,14),
        label='SubhaloMass')
plt.hist(np.log10(df['GroupMass']), bins=200, range=(9.5,14), alpha=0.7,
        label='GroupMass')
plt.legend()
plt.show()

# %%
plt.hist(np.log10(df['SubhaloMass']), bins=200, range=(10,14),
        label='SubhaloMass')
plt.hist(np.log10(df['SubhaloMass_dmo']), bins=200, range=(10,14), alpha=0.5,
        label='SubhaloMass_dmo', color='red')
plt.legend()
plt.show()

# %%
plt.hist(np.log10(df['GroupMass']), bins=200, range=(10,14),
        label='GroupMass')
plt.hist(np.log10(df['GroupMass_dmo']), bins=200, range=(10,14), alpha=0.5,
        label='GroupMass_dmo', color='red')
plt.legend()
plt.show()

# %% [markdown]
# ## <font color='Green'> Central Galaxies & a Clean Feature Set

# %% [markdown]
# #### What are SubhaloMass and GroupMass features?
# Ari: They are the same as GalpropMvir and HalopropMvir. They differ if using satellites, but are the same for centrals. There are a number of fields that can be removed because we are only looking at centrals
#
# Conclusion: I'll drop them.

# %% [markdown]
# #### Which mass measurements should I use?
# Ari: So the sim includes multiple ways of measuring halo properties. The TopHat values are the closest to what we used for the SAM. R for radii and V for velocities.  I think if you do the correlation analysis again you'll find that these are all highly correlated. We could use all Crit200 or all TopHat, it doesn't really matter. There is possibly some information if one compared the ratio of 2 of these, but I think that is extra feature engineering that we shouldn't bother with yet.
# The advantage of TopHat or Crit200 is they have an R and V which GroupMass /SubhaloMass doesn't.
#
# Conclusion: I'll use TopHat values since they are closer to what we used in SAM.
#
# #### <font color='DarkRed'> Q: How are these measurements of mass done? Why are they different? Where can I learn this?

# %%
df.columns.to_list()
# Out:
# ['SubhaloBHMass',
#  'SubhaloBHMdot',
#  'SubhaloGasMetallicity',
#  'SubhaloMass',
#  'SubhaloSFRinRad',
#  'SubhaloStarMetallicity',
#  'SubhaloVelDisp',
#  'SubhaloVmax',
#  'SubhaloVmaxRad',
#  'SubhaloRgas',
#  'SubhaloRstar',
#  'SubhaloMgas',
#  'SubhaloMstar',
#  'SubhaloCentral',
#  'GroupNsubs',
#  'GroupBHMass',
#  'GroupMass',
#  'Group_M_Crit200',
#  'Group_M_TopHat200',
#  'Group_R_Crit200',
#  'Group_R_TopHat200',
#  'SubhaloMHI',
#  'SubhaloMH2',
#  'SubhaloMass_dmo',
#  'SubhaloVelDisp_dmo',
#  'SubhaloVmax_dmo',
#  'SubhaloVmaxRad_dmo',
#  'SubhaloCentral_dmo',
#  'GroupNsubs_dmo',
#  'GroupMass_dmo',
#  'Group_M_Crit200_dmo',
#  'Group_M_TopHat200_dmo',
#  'Group_R_Crit200_dmo',
#  'Group_R_TopHat200_dmo',
#  'Group_V_TopHat200',
#  'Group_V_Crit200',
#  'GroupSpin',
#  'Group_V_TopHat200_dmo',
#  'Group_V_Crit200_dmo',
#  'GroupSpin_dmo']

# %%
# Drop the two columns that define central galaxies in SIMs and DMO;
# also drop SubhaloMass and GroupMass
# also drop Crit200 values
# DO NOT drop MHI and MH2 since in v3 dataset they are NOT empty columns
# drop GroupSpin bec it is spin of dark matter + stars; we only want spin of dark matter (GroupSpin_dmo)
df_centrals = df.drop(columns=['SubhaloCentral', 'SubhaloCentral_dmo',
                      'SubhaloMass', 'GroupMass', 'SubhaloMass_dmo', 'GroupMass_dmo',
                      'Group_M_Crit200' , 'Group_R_Crit200', 'Group_V_Crit200',
                      'Group_M_Crit200_dmo', 'Group_R_Crit200_dmo', 'Group_V_Crit200_dmo',
                      #'SubhaloMHI', 'SubhaloMH2',
                              'GroupSpin'])

# %%
df_centrals.shape
# Out:
# (21598, 27)

# %% [markdown]
# ## Correlations

# %% [markdown]
# ### <font color='DarkGreen'> Spearman Correlations of the complete raw dataset

# %%
df_corr = df.drop(columns=['SubhaloCentral'])
corr_df = df_corr.corr('spearman')
# corr_df = corr_df.sort_values('GalpropHalfRradius') # this is not a matrix where diagonal is 1 anymore; it only arranges half rad values from smallest to biggest
plt.figure(figsize=(40,40))
matrix = np.triu(corr_df) # take upper correlation matrix
sns.heatmap(corr_df, cmap="coolwarm",annot=True, mask=matrix)
plt.title("Spearman Correlation of TNG-SIM \n v3 Dataset w log10Mstar=8 galaxies included", fontsize = 20)
plt.ylabel("Features", fontsize = 20)
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_Spearman_correlation_matrix_v1.jpeg', dpi=500)
plt.show()

# %% [markdown]
# ### <font color='DarkGreen'> Spearman Correlations of the complete dimensionless dataset

# %%
df_1 = df.drop(columns=['SubhaloCentral', 'SubhaloCentral_dmo', #used to define centrals, but we have already chosen only centrals
                                      #'SubhaloMHI', 'SubhaloMH2', # NOT empty columns in v3 Dataset
                                      'GroupMass', 'GroupMass_dmo']) # drop since same with SubhaloMass

# %% [markdown]
# ### Conclusion: TopHat200 and Crit200 are almost the same as their _dmo corresponding values, drop dmo values

# %%
plt.hist(np.log10(df['Group_M_TopHat200']),
        bins=200, range=(10,14), label='Group_M_TopHat200')
plt.hist(np.log10(df['Group_M_TopHat200_dmo']),
        bins=200, range=(10,14), alpha=0.7, label='Group_M_TopHat200_dmo')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_M_TopHat200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_M_TopHat200_dmo and Group_M_TopHat200 are the same

# %%
plt.hist(np.log10(df['Group_R_TopHat200']),
        bins=200, label='Group_R_TopHat200', range=(1.8, 3.2))
plt.hist(np.log10(df['Group_R_TopHat200_dmo']),
        bins=200, alpha=0.7, label='Group_R_TopHat200_dmo', range=(1.8, 3.2))
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_R_TopHat200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_R_TopHat200_dmo and Group_R_TopHat200 are the same

# %%
plt.hist(np.log10(df['Group_V_TopHat200']),
        bins=200, label='Group_V_TopHat200', range=(1.6, 3.0))
plt.hist(np.log10(df['Group_V_TopHat200_dmo']),
        bins=200, alpha=0.7, label='Group_V_TopHat200_dmo', range=(1.6, 3.0))
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_V_TopHat200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_V_TopHat200_dmo and Group_V_TopHat200 are the same

# %%
plt.hist(np.log10(df['Group_M_Crit200']),
        bins=200, range=(10,14), label='Group_M_Crit200')
plt.hist(np.log10(df['Group_M_Crit200_dmo']),
        bins=200, range=(10,14), alpha=0.7, label='Group_M_Crit200_dmo')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_M_Crit200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_M_Crit200_dmo and Group_M_Crit200 are the same

# %%
plt.hist(np.log10(df['Group_R_Crit200']),
        bins=200, label='Group_R_Crit200', range=(1.8, 3.2))
plt.hist(np.log10(df['Group_R_Crit200_dmo']),
        bins=200, alpha=0.7, label='Group_R_Crit200_dmo', range=(1.8, 3.2))
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_R_Crit200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_R_Crit200_dmo and Group_R_Crit200 are the same

# %%
plt.hist(np.log10(df['Group_V_Crit200']),
        bins=200, label='Group_V_Crit200', range=(1.6, 3.0))
plt.hist(np.log10(df['Group_V_Crit200_dmo']),
        bins=200, alpha=0.7, label='Group_V_Crit200_dmo', range=(1.6, 3.0))
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_V_Crit200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_V_Crit200_dmo and Group_V_Crit200 are the same

# %% [markdown]
# ### TopHat200 vs Crit200 values

# %%
plt.hist(np.log10(df['Group_M_TopHat200']),
        bins=200, range=(10,14), label='Group_M_TopHat200')
plt.hist(np.log10(df['Group_M_Crit200']),
        bins=200, range=(10,14), alpha=0.5, label='Group_M_Crit200' , color='r')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_M_TopHat200_vs_Crit200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_M_TopHat200 and Group_M_Crit200 are very similar

# %%
plt.hist(np.log10(df['Group_R_TopHat200']),
        bins=200, range=(1.8, 3.2), label='Group_R_TopHat200')
plt.hist(np.log10(df['Group_R_Crit200']),
        bins=200, range=(1.8, 3.2), alpha=0.5, label='Group_R_Crit200', color='r')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_R_TopHat200_vs_Crit200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_R_TopHat200 and Group_R_Crit200 have similar spread, but Crit200 peak is shifted to the left by 0.2

# %%
plt.hist(np.log10(df['Group_V_TopHat200']),
        bins=200, label='Group_V_TopHat200', range=(1.6, 3.0))
plt.hist(np.log10(df['Group_V_Crit200']),
        bins=200, alpha=0.5, label='Group_V_Crit200', range=(1.6, 3.0), color='r')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_V_TopHat200_vs_Crit200.jpeg', dpi=500)
plt.show()

# Conclusion: Group_V_TopHat200 and Group_V_Crit200 are very similar

# %% [markdown]
# ### TopHat200 vs SubhaloMass values

# %%
plt.hist(np.log10(df['Group_M_TopHat200']),
        bins=200, range=(10,14), label='Group_M_TopHat200', color='darkblue')
plt.hist(np.log10(df['SubhaloMass']),
        bins=200, range=(10,14), alpha=0.5, label='SubhaloMass' , color='y')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_M_TopHat200_vs_SubhaloMass.jpeg', dpi=500)
plt.show()

# Conclusion: Group_M_TopHat200 and SubhaloMass are almost the same

# %%
plt.hist(np.log10(df['Group_M_TopHat200_dmo']),
        bins=200, range=(10,14), label='Group_M_TopHat200_dmo', color='darkblue')
plt.hist(np.log10(df['SubhaloMass_dmo']),
        bins=200, range=(10,14), alpha=0.5, label='SubhaloMass_dmo' , color='y')
plt.legend()
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_Group_M_TopHat200_dmo_vs_SubhaloMass_dmo.jpeg', dpi=500)
plt.show()

# Conclusion: Group_M_TopHat200_dmo and SubhaloMass_dmo are almost the same

# %% [markdown]
# ### Define functions

# %%
df.columns.to_list()
# Out:
# ['SubhaloBHMass',
#  'SubhaloBHMdot',
#  'SubhaloGasMetallicity',
#  'SubhaloMass',
#  'SubhaloSFRinRad',
#  'SubhaloStarMetallicity',
#  'SubhaloVelDisp',
#  'SubhaloVmax',
#  'SubhaloVmaxRad',
#  'SubhaloRgas',
#  'SubhaloRstar',
#  'SubhaloMgas',
#  'SubhaloMstar',
#  'SubhaloCentral',
#  'GroupNsubs',
#  'GroupBHMass',
#  'GroupMass',
#  'Group_M_Crit200',
#  'Group_M_TopHat200',
#  'Group_R_Crit200',
#  'Group_R_TopHat200',
#  'SubhaloMHI',
#  'SubhaloMH2',
#  'SubhaloMass_dmo',
#  'SubhaloVelDisp_dmo',
#  'SubhaloVmax_dmo',
#  'SubhaloVmaxRad_dmo',
#  'SubhaloCentral_dmo',
#  'GroupNsubs_dmo',
#  'GroupMass_dmo',
#  'Group_M_Crit200_dmo',
#  'Group_M_TopHat200_dmo',
#  'Group_R_Crit200_dmo',
#  'Group_R_TopHat200_dmo',
#  'Group_V_TopHat200',
#  'Group_V_Crit200',
#  'GroupSpin',
#  'Group_V_TopHat200_dmo',
#  'Group_V_Crit200_dmo',
#  'GroupSpin_dmo']

# %%
def normalization_func(df):
    '''
    Normalizes the dataset by dividing all masses by halo mass, and galaxy size by halo size

    '''
#     could also use the method below
#     df_log_mass_filtered.loc[:,'GalpropNormMstar']=df_log_mass_filtered.loc[:,'GalpropMstar'].div(df_log_mass_filtered.HalopropMvir, axis=0)
    
    df =df.copy()
    
    # define halomass, halo radius and halo velocity
    halomass=df.loc[:,'Group_M_TopHat200'] # Q: ShoulD I use this, or the _dmo version of it? Why? Ans: Looking at the histogram, they seem to be the same, so use this mass
    halorad= df.loc[:,'Group_R_TopHat200']
    halovel= df.loc[:,'Group_V_TopHat200']
    
    # dimensionless form of halfmass radius, Rgas and the radius at which Vmax occurs
    df.loc[:,'SubhaloRstar_0D']=df.loc[:,'SubhaloRstar']/halorad # halfmass radius
    df.loc[:,'SubhaloRgas_0D']=df.loc[:,'SubhaloRgas']/halorad # galaxy size in gas? 
    df.loc[:,'SubhaloVmaxRad_0D']=df.loc[:,'SubhaloVmaxRad']/halorad # Vmax is the maximum circular velocity. VmaxRad is the radius at which Vmax occurs. 
    df.loc[:,'SubhaloVmaxRad_dmo_0D']=df.loc[:,'SubhaloVmaxRad_dmo']/halorad
    
    # dimensionless form of circular velocities
    df.loc[:,'SubhaloVmax_0D']=df.loc[:,'SubhaloVmax']/halovel 
    df.loc[:,'SubhaloVmax_dmo_0D']=df.loc[:,'SubhaloVmax_dmo']/halovel
    df.loc[:,'SubhaloVelDisp_0D']=df.loc[:,'SubhaloVelDisp']/halovel 
    df.loc[:,'SubhaloVelDisp_dmo_0D']=df.loc[:,'SubhaloVelDisp_dmo']/halovel
   
    
    # dimensionless form of masses
    df.loc[:,'SubhaloMgas_0D']=df.loc[:,'SubhaloMgas']/halomass 
    df.loc[:,'SubhaloMstar_0D']=df.loc[:,'SubhaloMstar']/halomass
    df.loc[:,'SubhaloBHMass_0D']=df.loc[:,'SubhaloBHMass']/halomass
    df.loc[:,'GroupBHMass_0D']=df.loc[:,'GroupBHMass']/halomass
    df.loc[:,'SubhaloBHMdot_0D']=df.loc[:,'SubhaloBHMdot']/halomass
    df.loc[:,'SubhaloMHI_0D']=df.loc[:,'SubhaloMHI']/halomass
    df.loc[:,'SubhaloMH2_0D']=df.loc[:,'SubhaloMH2']/halomass
    
    # dimensionless form of different forms of halo sizes (not very imp)
    df.loc[:,'Group_R_TopHat200_0D']=df.loc[:,'Group_R_TopHat200']/halorad # this is 1
    df.loc[:,'Group_R_TopHat200_dmo_0D']=df.loc[:,'Group_R_TopHat200_dmo']/halorad # this is R_TopHat200_dmo/R_TopHat200
    df.loc[:,'Group_R_Crit200_0D']=df.loc[:,'Group_R_Crit200']/halorad # this is # this is R_Crit200/R_TopHat200
    df.loc[:,'Group_R_Crit200_dmo_0D']=df.loc[:,'Group_R_Crit200_dmo']/halorad # this is R_Crit200_dmo/R_TopHat200

    # dimensionless form of different forms of halo masses (not very imp)
    df.loc[:,'Group_M_TopHat200_0D']=df.loc[:,'Group_M_TopHat200']/halomass # this is 1
    df.loc[:,'Group_M_TopHat200_dmo_0D']=df.loc[:,'Group_M_TopHat200_dmo']/halomass # this is M_TopHat200_dmo/M_TopHat200, should be almost 1
    df.loc[:,'Group_M_Crit200_0D']=df.loc[:,'Group_M_Crit200']/halomass # this is # this is M_Crit200/M_TopHat200
    df.loc[:,'Group_M_Crit200_dmo_0D']=df.loc[:,'Group_M_Crit200_dmo']/halomass # this is M_Crit200_dmo/M_TopHat200
    df.loc[:,'SubhaloMass_0D']=df.loc[:,'SubhaloMass']/halomass
    df.loc[:,'SubhaloMass_dmo_0D']=df.loc[:,'SubhaloMass_dmo']/halomass
#     df.loc[:,'GroupMass_0D']=df.loc[:,'GroupMass']/halomass
#     df.loc[:,'GroupMass_dmo_0D']=df.loc[:,'GroupMass_dmo']/halomass
    
    # dimensionless form of different forms of halo velocities (not very imp)
    df.loc[:,'Group_V_TopHat200_0D']=df.loc[:,'Group_V_TopHat200']/halovel # this is 1
    df.loc[:,'Group_V_TopHat200_dmo_0D']=df.loc[:,'Group_V_TopHat200_dmo']/halovel # this is V_TopHat200_dmo/V_TopHat200, should be almost 1
    df.loc[:,'Group_V_Crit200_0D']=df.loc[:,'Group_V_Crit200']/halovel # this is # this is V_Crit200/V_TopHat200
    df.loc[:,'Group_V_Crit200_dmo_0D']=df.loc[:,'Group_V_Crit200_dmo']/halovel # this is V_Crit200_dmo/V_TopHat200

    # 28 lines
    return df

# %%
df_0D = normalization_func(df_1)

# %%
df_0D.shape
# Out:
# (21598, 65)

# %%
df_0D_clean = df_0D.drop(columns=['Group_M_TopHat200', 'Group_R_TopHat200', 'Group_V_TopHat200', # cols used for normalization
                                'Group_M_TopHat200_0D', 'Group_R_TopHat200_0D', 'Group_V_TopHat200_0D',
                                'Group_M_TopHat200_dmo', 'Group_R_TopHat200_dmo', 'Group_V_TopHat200_dmo',
                                'Group_M_Crit200', 'Group_R_Crit200', 'Group_V_Crit200',
                                'Group_M_Crit200_dmo', 'Group_R_Crit200_dmo', 'Group_V_Crit200_dmo',
                                'SubhaloMass', 'SubhaloMass_dmo',
                                'SubhaloVmax', 'SubhaloVmax_dmo',
                                'SubhaloVelDisp', 'SubhaloVelDisp_dmo',
                                'SubhaloVmaxRad', 'SubhaloVmaxRad_dmo',
                                'SubhaloRstar', 'SubhaloRgas',
                                'SubhaloMstar', 'SubhaloMgas',
                                'SubhaloBHMass', 'GroupBHMass', 'SubhaloBHMdot',
                                'SubhaloMHI', 'SubhaloMH2'])

# %%
df_0D_clean.shape
# Out:
# (21598, 33)

# %%
df_0D_clean
# Out:
#         SubhaloGasMetallicity  SubhaloSFRinRad  SubhaloStarMetallicity  \
# 0                    0.007718         0.195825                0.028622
# 17185                0.004368         1.657662                0.020940
# 31342                0.005708         1.530534                0.022085
# 41582                0.014258        98.666870                0.023172
# 52618                0.004526         1.724860                0.021753
# ...                       ...              ...                     ...
# 901833               0.000000         0.000000                0.006870
# 916946               0.000000         0.000000                0.011401
# 925463               0.000000         0.000000                0.007651
# 931184               0.000000         0.000000                0.010493
# 942269               0.000000         0.000000                0.009866
#
#         GroupNsubs  GroupNsubs_dmo  GroupSpin  GroupSpin_dmo  SubhaloRstar_0D  \
# 0            17185         24681.0   0.015910       0.016995         0.034353
# 17185        14157         19381.0   0.013266       0.012785         0.062079
# 31342        10240         14812.0   0.034117       0.032441         0.044287
# 41582        11036         15339.0   0.021438       0.026528         0.018732
# 52618         8113         11085.0   0.043523       0.037578         0.029782
# ...            ...             ...        ...            ...              ...
# 901833           1           946.0   0.003929       0.000060         0.062353
# 916946           1             2.0   0.006042       0.009550         0.062450
# 925463           1          3108.0   0.008419       0.000036         0.081380
# 931184           1           439.0   0.004932       0.000077         0.058209
# 942269           1          2996.0   0.009180       0.000023         0.076472
#
#         SubhaloRgas_0D  SubhaloVmaxRad_0D  SubhaloVmaxRad_dmo_0D  \
# 0             0.454753           0.237651               0.265355
# 17185         0.481878           0.674877               0.686944
# 31342         0.407886           0.470064               0.437582
# 41582         0.401898           0.276922               0.294140
# 52618         0.421826           0.578710               0.594200
# ...                ...                ...                    ...
# 901833        0.000000           0.080860               0.125802
# 916946        0.000000           0.051728               0.097652
# 925463        0.000000           0.076249               0.107656
# 931184        0.000000           0.060505               0.096570
# 942269        0.000000           0.064070               0.127375
#
#         SubhaloVmax_0D  SubhaloVmax_dmo_0D  SubhaloVelDisp_0D  \
# 0             1.012913            0.995211           0.612050
# 17185         0.942593            0.899316           0.584577
# 31342         1.043623            1.022490           0.601488
# 41582         1.101144            1.083645           0.614389
# 52618         0.942282            0.921877           0.580719
# ...                ...                 ...                ...
# 901833        1.957614            2.307196           1.013281
# 916946        2.369753            2.803814           1.111645
# 925463        2.098586            2.485034           1.045201
# 931184        2.381920            2.846867           1.149827
# 942269        2.137975            2.781428           0.961582
#
#         SubhaloVelDisp_dmo_0D  SubhaloMgas_0D  SubhaloMstar_0D  \
# 0                    0.643730        0.027866         0.007087
# 17185                0.614626        0.083750         0.004260
# 31342                0.630259        0.073389         0.006562
# 41582                0.642960        0.045557         0.006070
# 52618                0.612611        0.084787         0.003724
# ...                       ...             ...              ...
# 901833               1.204467        0.000000         0.023008
# 916946               1.389850        0.000000         0.046769
# 925463               1.281469        0.000000         0.033929
# 931184               1.447181        0.000000         0.045603
# 942269               1.447491        0.000000         0.040171
#
#         SubhaloBHMass_0D  GroupBHMass_0D  SubhaloBHMdot_0D  SubhaloMHI_0D  \
# 0               0.000022        0.000081      8.972381e-19       0.000026
# 17185           0.000016        0.000055      1.997091e-19       0.000016
# 31342           0.000031        0.000067      9.622102e-19       0.000011
# 41582           0.000022        0.000115      5.275731e-18       0.000092
# 52618           0.000012        0.000052      2.908380e-18       0.000031
# ...                  ...             ...               ...            ...
# 901833          0.000000        0.000000      0.000000e+00       0.000000
# 916946          0.000000        0.000000      0.000000e+00       0.000000
# 925463          0.000000        0.000000      0.000000e+00       0.000000
# 931184          0.000000        0.000000      0.000000e+00       0.000000
# 942269          0.000000        0.000000      0.000000e+00       0.000000
#
#         SubhaloMH2_0D  Group_R_TopHat200_dmo_0D  Group_R_Crit200_0D  \
# 0            0.000025                  0.995465            0.747883
# 17185        0.000019                  0.982731            0.727770
# 31342        0.000013                  0.997390            0.754502
# 41582        0.000336                  0.989166            0.743115
# 52618        0.000044                  0.998056            0.752716
# ...               ...                       ...                 ...
# 901833       0.000000                 12.302930            0.786731
# 916946       0.000000                  1.318750            0.788617
# 925463       0.000000                 21.487074            0.785316
# 931184       0.000000                 13.592943            0.776077
# 942269       0.000000                 22.191920            0.776409
#
#         Group_R_Crit200_dmo_0D  Group_M_TopHat200_dmo_0D  Group_M_Crit200_0D  \
# 0                     0.739507                  0.986359            0.817359
# 17185                 0.707076                  0.949029            0.753166
# 31342                 0.745619                  0.992264            0.839354
# 41582                 0.732974                  0.967882            0.801853
# 52618                 0.753205                  0.994209            0.833289
# ...                        ...                       ...                 ...
# 901833                9.181655               1862.277939            0.951639
# 916946                1.030505                  2.293809            0.958482
# 925463               16.048983               9920.941479            0.946253
# 931184               10.382330               2511.226312            0.913275
# 942269               16.453156              10930.194084            0.914532
#
#         Group_M_Crit200_dmo_0D  SubhaloMass_0D  SubhaloMass_dmo_0D  \
# 0                     0.790180        0.879883            0.921318
# 17185                 0.690730        0.801144            0.795196
# 31342                 0.809951        0.852074            0.858067
# 41582                 0.769542        0.952372            0.978385
# 52618                 0.834886        0.751044            0.741059
# ...                        ...             ...                 ...
# 901833             1512.623483        0.916632            1.518184
# 916946                2.138695        0.947600            2.135170
# 925463             8077.335087        0.863408            1.894593
# 931184             2186.563958        0.839066            1.854847
# 942269             8703.668399        0.900904            2.286037
#
#         Group_V_TopHat200_dmo_0D  Group_V_Crit200_0D  Group_V_Crit200_dmo_0D
# 0                       0.995416            1.045417                1.033693
# 17185                   0.982703            1.017298                0.988374
# 31342                   0.997427            1.054732                1.042247
# 41582                   0.989183            1.038770                1.024641
# 52618                   0.998071            1.052161                1.052827
# ...                          ...                 ...                     ...
# 901833                 12.303197            1.099823               12.835268
# 916946                  1.318856            1.102450                1.440620
# 925463                 21.487594            1.097695               22.434184
# 931184                 13.592088            1.084797               14.512214
# 942269                 22.193026            1.085311               22.999933
#
# [21598 rows x 33 columns]

# %%
df_0D_clean.columns.to_list()
# Out:
# ['SubhaloGasMetallicity',
#  'SubhaloSFRinRad',
#  'SubhaloStarMetallicity',
#  'GroupNsubs',
#  'GroupNsubs_dmo',
#  'GroupSpin',
#  'GroupSpin_dmo',
#  'SubhaloRstar_0D',
#  'SubhaloRgas_0D',
#  'SubhaloVmaxRad_0D',
#  'SubhaloVmaxRad_dmo_0D',
#  'SubhaloVmax_0D',
#  'SubhaloVmax_dmo_0D',
#  'SubhaloVelDisp_0D',
#  'SubhaloVelDisp_dmo_0D',
#  'SubhaloMgas_0D',
#  'SubhaloMstar_0D',
#  'SubhaloBHMass_0D',
#  'GroupBHMass_0D',
#  'SubhaloBHMdot_0D',
#  'SubhaloMHI_0D',
#  'SubhaloMH2_0D',
#  'Group_R_TopHat200_dmo_0D',
#  'Group_R_Crit200_0D',
#  'Group_R_Crit200_dmo_0D',
#  'Group_M_TopHat200_dmo_0D',
#  'Group_M_Crit200_0D',
#  'Group_M_Crit200_dmo_0D',
#  'SubhaloMass_0D',
#  'SubhaloMass_dmo_0D',
#  'Group_V_TopHat200_dmo_0D',
#  'Group_V_Crit200_0D',
#  'Group_V_Crit200_dmo_0D']

# %%
# Drop the two columns that define central galaxies in SIMs and DMO;
# also drop SubhaloMass and GroupMass
# also drop Crit200 values
# DO NOT drop MHI and MH2 since they are NOT empty columns in v3 Dataset
# drop GroupSpin bec it is spin of dark matter + stars; we only want spin of dark matter (GroupSpin_dmo)
df_centrals_0D = df_0D_clean.drop(columns=[ 'SubhaloMass_0D', 'SubhaloMass_dmo_0D',
                      'Group_M_Crit200_0D' , 'Group_R_Crit200_0D', 'Group_V_Crit200_0D',
                      'Group_M_Crit200_dmo_0D', 'Group_R_Crit200_dmo_0D', 'Group_V_Crit200_dmo_0D',
                      'GroupSpin'])

# %%
df_centrals_0D.shape
# Out:
# (21598, 24)

# %%
# df_centrals (shape (21598, 27))
# is the raw dataset to be used for ML (note: may need to remove the TopHat200_dmo values)
df_centrals.columns.to_list()
# Out:
# ['SubhaloBHMass',
#  'SubhaloBHMdot',
#  'SubhaloGasMetallicity',
#  'SubhaloSFRinRad',
#  'SubhaloStarMetallicity',
#  'SubhaloVelDisp',
#  'SubhaloVmax',
#  'SubhaloVmaxRad',
#  'SubhaloRgas',
#  'SubhaloRstar',
#  'SubhaloMgas',
#  'SubhaloMstar',
#  'GroupNsubs',
#  'GroupBHMass',
#  'Group_M_TopHat200',
#  'Group_R_TopHat200',
#  'SubhaloMHI',
#  'SubhaloMH2',
#  'SubhaloVelDisp_dmo',
#  'SubhaloVmax_dmo',
#  'SubhaloVmaxRad_dmo',
#  'GroupNsubs_dmo',
#  'Group_M_TopHat200_dmo',
#  'Group_R_TopHat200_dmo',
#  'Group_V_TopHat200',
#  'Group_V_TopHat200_dmo',
#  'GroupSpin_dmo']

# %%
# df_centrals_0D (shape (21598, 24)) is the dimensionless dataset to be used for ML 
#(note: may need to remove the TopHat200_dmo values;
# note2: this dataset has 3 features less because they are the features used to make it dimensionless)

df_centrals_0D.columns.to_list()
# Out:
# ['SubhaloGasMetallicity',
#  'SubhaloSFRinRad',
#  'SubhaloStarMetallicity',
#  'GroupNsubs',
#  'GroupNsubs_dmo',
#  'GroupSpin_dmo',
#  'SubhaloRstar_0D',
#  'SubhaloRgas_0D',
#  'SubhaloVmaxRad_0D',
#  'SubhaloVmaxRad_dmo_0D',
#  'SubhaloVmax_0D',
#  'SubhaloVmax_dmo_0D',
#  'SubhaloVelDisp_0D',
#  'SubhaloVelDisp_dmo_0D',
#  'SubhaloMgas_0D',
#  'SubhaloMstar_0D',
#  'SubhaloBHMass_0D',
#  'GroupBHMass_0D',
#  'SubhaloBHMdot_0D',
#  'Group_R_TopHat200_dmo_0D',
#  'Group_M_TopHat200_dmo_0D',
#  'Group_V_TopHat200_dmo_0D']

# %% [markdown]
# df_centrals is the raw dataset to use for ML
#
# df_centrals_0D is the dimensionless dataset to use for ML
#
# In both cases, the _dmo values should be removed before analysis.

# %%
df_centrals_raw = df_centrals.drop(columns=[ 'SubhaloVelDisp_dmo','SubhaloVmax_dmo','SubhaloVmaxRad_dmo',
                                             'GroupNsubs_dmo','Group_M_TopHat200_dmo','Group_R_TopHat200_dmo', 
                                             'Group_V_TopHat200_dmo'])

# %%
# 17 available features to predict target (Rstar)
df_centrals_raw.shape
# Out:
# (21598, 20)

# %% [markdown]
# ## Save the RAW Dataset

# %%
# save the raw dataset
# df_centrals_raw.to_csv('TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_Raw_Dataset.csv', index=False)

# %%
df_centrals_0D_final = df_centrals_0D.drop(columns=['SubhaloVelDisp_dmo_0D', 'SubhaloVmax_dmo_0D', 'SubhaloVmaxRad_dmo_0D',
                                                   'GroupNsubs_dmo', 'Group_M_TopHat200_dmo_0D', 'Group_R_TopHat200_dmo_0D',
                                                   'Group_V_TopHat200_dmo_0D'])

# %%
# 14 available features to predict target (Rstar)
df_centrals_0D_final.shape
# Out:
# (21598, 17)

# %% [markdown]
# ## Save the 0D Dataset

# %%
# save the dimensionless dataset
# df_centrals_0D_final.to_csv('TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_0D_Dataset.csv', index=False)

# %% [markdown]
# ### <font color='DarkGreen'> Spearman Correlations of the complete D0 dataset

# %%
corr_df_0D = df_0D_clean.corr('spearman')
# corr_df = corr_df.sort_values('GalpropHalfRradius') # this is not a matrix where diagonal is 1 anymore; it only arranges half rad values from smallest to biggest
plt.figure(figsize=(40,40))
matrix = np.triu(corr_df_0D) # take upper correlation matrix
sns.heatmap(corr_df_0D, cmap="coolwarm",annot=True, mask=matrix)
plt.title("Spearman Correlation of 0D TNG-SIM \n v3 Dataset w log10Mstar=8 gals included", fontsize = 20)
plt.ylabel("Features", fontsize = 20)
# plt.savefig('TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_Spearman_correlation_matrix_0Ddataset_v1.jpeg', dpi=500)
plt.show()

# %% [markdown]
# ### <font color='darkviolet'> Size, Mass and Halo Spin plot

# %%
mass_size_corr = round(stats.spearmanr(df['SubhaloMstar'], 
                                               df['SubhaloRstar'])[0], 2)
# SFR_size_corr = round(stats.spearmanr(df_centrals_log['GalpropLogSfr'], 
#                                               df_centrals_log['GalpropLogHalfRadius'] )[0], 2)
# SFR_mass_corr = round(stats.spearmanr(df_centrals_log['GalpropLogSfr'], 
#                                               df_centrals_log['GalpropLogMstar'] )[0], 2)
mom_size_corr = round(stats.spearmanr(df['GroupSpin_dmo'], 
                                              df['SubhaloRstar'])[0], 2)
print('mass_size_corr:', mass_size_corr)
# print('SFR_size_corr:', SFR_size_corr)
# print('SFR_mass_corr:', SFR_mass_corr)
print('mom_size_corr:', mom_size_corr)
# Out:
# mass_size_corr: 0.44
# mom_size_corr: 0.19

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,5))
fig.suptitle('TNG-SIM Central Galaxies v3: Size, Mass and Spin  ', fontsize=16, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

im1 = ax1.scatter(np.log10(df['SubhaloMstar']), np.log10(df['SubhaloRstar']), 
                    s=3, marker='.', alpha=0.7) # , vmin=-2, vmax=1.0)
#                   c = (df_log_mass_filtered['GalpropLogSfr']),  s=3, marker='.', alpha=0.7 , vmin=-2, vmax=1.0)#, label=label)

# ax1.set_xlim([8.0, 11.5])
# ax1.set_xticks([8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0])
ax1.set_ylim([-0.5,2.0])
ax1.set_title('Size vs Mass')
ax1.set_xlabel('$\log_{10} $  Galaxy Mass $[M_\odot] $')
ax1.set_ylabel('$\log_{10} $ Galaxy Size [kpc] ')
# ax1.legend(loc='lower right', shadow=True)


label = 'mass-size corr={} \n spin-size corr={}'.format(mass_size_corr, mom_size_corr )
im2 = ax2.scatter(df['GroupSpin_dmo'], np.log10(df['SubhaloRstar']), 
                     s=3, marker='.', alpha=0.7,label= label) #, vmin=-2, vmax=1.0)
#                   c = (df_log_mass_filtered['GalpropLogSfr']),  s=3, marker='.', alpha=0.7,label= label, vmin=-2, vmax=1.0)

# ax2.set_xlim([0.0,0.15])
# ax2.set_xticks([ 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3])
# ax2.set_ylim([-3.0, 1.1])
ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')
ax2.legend(loc='lower right' , shadow=True)

# fig.subplots_adjust(right=0.8)
# cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
# fig.colorbar(im2, cax=cbar_ax)

# plt.savefig("TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_centrals_Mass_Size_AngMom.jpeg", dpi=500)
plt.show()

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,5))
fig.suptitle('TNG-SIM Central Galaxies v3: Size, Mass and Spin  ', fontsize=16, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

im1 = ax1.scatter(np.log10(df['SubhaloMstar']), np.log10(df['SubhaloRstar']), 
#                     s=3, marker='.', alpha=0.7) # , vmin=-2, vmax=1.0)
                  c = (df.loc[:,'SubhaloMgas'].apply(lambda x: np.log10(x) if x>0 else 0)), 
                  s=3, marker='.', cmap='Spectral', alpha=0.7 , vmin=8.5, vmax=10.5)#, label=label)

ax1.set_xlim([9.0, 12.0])
# ax1.set_xticks([8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0])
ax1.set_ylim([-0.5,2.0])
ax1.set_title('Size vs Mass')
ax1.set_xlabel('$\log_{10} $  Galaxy Mass $[M_\odot] $')
ax1.set_ylabel('$\log_{10} $ Galaxy Size [kpc] ')
# ax1.legend(loc='lower right', shadow=True)


label = r'$\log_{10}M_{gas}$' + '\n mass-size corr={} \n spin-size corr={}'.format(mass_size_corr, mom_size_corr )
im2 = ax2.scatter(df['GroupSpin_dmo'], np.log10(df['SubhaloRstar']), 
#                      s=3, marker='.', alpha=0.7,label= label) #, vmin=-2, vmax=1.0)
                  c  = (df.loc[:,'SubhaloMgas'].apply(lambda x: np.log10(x) if x>0 else 0)),  
                  s=3, marker='.', alpha=0.7,cmap='Spectral', label= label, vmin=8.5, vmax=10.5)

ax2.set_xlim([0.0,0.1])
ax2.set_xticks([ 0.02, 0.04, 0.06, 0.08, 0.1])
# ax2.set_ylim([-3.0, 1.1])
ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')
ax2.legend(loc='lower right' , shadow=True)

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
fig.colorbar(im2, cax=cbar_ax)

# plt.savefig("TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_centrals_Mass_Size_AngMom_colorMgas.jpeg", dpi=500)
plt.show()

# %%
plt.hist((df.loc[:,'SubhaloMgas'].apply(lambda x: np.log10(x) if x>0 else 0)),
        bins=200, range=(5,13))
plt.show()

# %% [raw]
# # 818 galaxies have Mgas=0
# df['SubhaloMgas'].replace(0, np.nan).isnull().sum()

# %%
plt.hist(df.loc[:, 'GroupSpin_dmo'])
plt.show()

# %%
plt.hist(np.log10(df['SubhaloMstar']))
plt.show()

# %%
plt.hist(np.log10(df['SubhaloRstar']))
plt.show()

# %%
plt.hist(np.log10(df.loc[:, 'SubhaloVmaxRad']))
plt.show()

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,5))
fig.suptitle('TNG-SIM Central Galaxies v3: Size, Mass and Spin  ', fontsize=16, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

im1 = ax1.scatter(np.log10(df['SubhaloMstar']), np.log10(df['SubhaloRstar']), 
#                     s=3, marker='.', alpha=0.7) # , vmin=-2, vmax=1.0)
                  c = np.log10(df.loc[:, 'SubhaloVmaxRad']), 
                  s=3, marker='.', cmap='Spectral', alpha=0.7 , vmin=0.5, vmax=1.5)#, label=label)

ax1.set_xlim([9.0, 12.0])
# ax1.set_xticks([8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0])
ax1.set_ylim([-0.5,2.0])
ax1.set_title('Size vs Mass')
ax1.set_xlabel('$\log_{10} $  Galaxy Mass $[M_\odot] $')
ax1.set_ylabel('$\log_{10} $ Galaxy Size [kpc] ')
# ax1.legend(loc='lower right', shadow=True)


label = r'$V_{max}Rad$' + '\n mass-size corr={} \n spin-size corr={}'.format(mass_size_corr, mom_size_corr )
im2 = ax2.scatter(df['GroupSpin_dmo'], np.log10(df['SubhaloRstar']), 
#                      s=3, marker='.', alpha=0.7,label= label) #, vmin=-2, vmax=1.0)
                  c  = np.log10(df.loc[:, 'SubhaloVmaxRad']),  
                  s=3, marker='.', alpha=0.7,cmap='Spectral', label= label, vmin=0.5, vmax=1.5)

ax2.set_xlim([0.0,0.1])
ax2.set_xticks([ 0.02, 0.04, 0.06, 0.08, 0.1])
# ax2.set_ylim([-3.0, 1.1])
ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')
ax2.legend(loc='lower right' , shadow=True)

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
fig.colorbar(im2, cax=cbar_ax)

# plt.savefig("TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_centrals_Mass_Size_AngMom_colorVmaxRad.jpeg", dpi=500)
plt.show()

# %% [markdown]
# ### 0D Dataset Mass, Size, Spin Plot

# %%
mass_size_corr_0D = round(stats.spearmanr(df_0D_clean['SubhaloMstar_0D'], 
                                               df_0D_clean['SubhaloRstar_0D'])[0], 2)
# SFR_size_corr = round(stats.spearmanr(df_centrals_log['GalpropLogSfr'], 
#                                               df_centrals_log['GalpropLogHalfRadius'] )[0], 2)
# SFR_mass_corr = round(stats.spearmanr(df_centrals_log['GalpropLogSfr'], 
#                                               df_centrals_log['GalpropLogMstar'] )[0], 2)
mom_size_corr_0D = round(stats.spearmanr(df_0D_clean['GroupSpin_dmo'], 
                                              df_0D_clean['SubhaloRstar_0D'])[0], 2)
print('mass_size_corr_0D:', mass_size_corr_0D)
# print('SFR_size_corr:', SFR_size_corr)
# print('SFR_mass_corr:', SFR_mass_corr)
print('mom_size_corr_0D:', mom_size_corr_0D)
# Out:
# mass_size_corr_0D: -0.08
# mom_size_corr_0D: 0.06

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,5))
fig.suptitle('TNG-SIM Central Galaxies v3:0D Size, 0D Mass and Halo Spin  ', fontsize=14, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

im1 = ax1.scatter(df_0D_clean['SubhaloMstar_0D'], df_0D_clean['SubhaloRstar_0D'], 
                    s=3, marker='.', alpha=0.7) # , vmin=-2, vmax=1.0)
#                   c = (df_log_mass_filtered['GalpropLogSfr']),  s=3, marker='.', alpha=0.7 , vmin=-2, vmax=1.0)#, label=label)

ax1.set_xlim([0.0, 0.05])
# ax1.set_xticks([8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0])
ax1.set_ylim([0.0,0.05])
ax1.set_title('Size vs Mass')
ax1.set_xlabel('0D Galaxy Mass')
ax1.set_ylabel('0D Galaxy Size')
# ax1.legend(loc='lower right', shadow=True)


label = '0D mass-size corr={} \n 0D spin-size corr={}'.format(mass_size_corr_0D, mom_size_corr_0D )
im2 = ax2.scatter(df_0D_clean['GroupSpin_dmo'], df_0D_clean['SubhaloRstar_0D'], 
                     s=3, marker='.', alpha=0.7,label= label) #, vmin=-2, vmax=1.0)
#                   c = (df_log_mass_filtered['GalpropLogSfr']),  s=3, marker='.', alpha=0.7,label= label, vmin=-2, vmax=1.0)

ax2.set_xlim([0.0,0.1])
ax2.set_xticks([ 0.02, 0.04, 0.06, 0.08, 0.1])
# ax2.set_ylim([-3.0, 1.1])
ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')
ax2.legend(loc='upper right' , shadow=True)

# fig.subplots_adjust(right=0.8)
# cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
# fig.colorbar(im2, cax=cbar_ax)

# plt.savefig("TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_centrals_0D_Mass_Size_AngMom.jpeg", dpi=500)
plt.show()

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,5))
fig.suptitle('TNG-SIM Central Galaxies v3:0D Size, 0D Mass and Halo Spin  ', fontsize=14, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

im1 = ax1.scatter(df_0D_clean['SubhaloMstar_0D'], df_0D_clean['SubhaloRstar_0D'], 
#                     s=3, marker='.', alpha=0.7) 
                  c = df_0D_clean.loc[:,'SubhaloMgas_0D'],  s=3, marker='.', 
                  cmap='Spectral', alpha=0.7, vmin=0.005, vmax=0.03)#, label=label)

ax1.set_xlim([0.0, 0.05])
# ax1.set_xticks([8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0])
ax1.set_ylim([0.0,0.05])
ax1.set_title('Size vs Mass')
ax1.set_xlabel('0D Galaxy Mass')
ax1.set_ylabel('0D Galaxy Size')
# ax1.legend(loc='lower right', shadow=True)


label = ' 0D Mgas \n 0D mass-size corr={} \n 0D spin-size corr={}'.format(mass_size_corr_0D, mom_size_corr_0D )
im2 = ax2.scatter(df_0D_clean['GroupSpin_dmo'], df_0D_clean['SubhaloRstar_0D'], 
#                      s=3, marker='.', alpha=0.7,label= label)
                  c = df_0D_clean.loc[:,'SubhaloMgas_0D'],  s=3, marker='.', 
                  cmap='Spectral', alpha=0.7,label= label, vmin=0.005, vmax=0.03)

ax2.set_xlim([0.0,0.1])
ax2.set_xticks([ 0.02, 0.04, 0.06, 0.08, 0.1])
# ax2.set_ylim([-3.0, 1.1])
ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')
ax2.legend(loc='upper right' , shadow=True)

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
fig.colorbar(im2, cax=cbar_ax)

# plt.savefig("TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_centrals_0D_Mass_Size_AngMom_colorMgas.jpeg", dpi=500)
plt.show()

# %%
plt.hist(df_0D_clean.loc[:,'SubhaloMgas_0D'], bins=200)
plt.show()

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,5))
fig.suptitle('TNG-SIM Central Galaxies v3:0D Size, 0D Mass and Halo Spin  ', fontsize=14, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

im1 = ax1.scatter(df_0D_clean['SubhaloMstar_0D'], df_0D_clean['SubhaloRstar_0D'], 
#                     s=3, marker='.', alpha=0.7) 
                  c = df_0D_clean.loc[:,'SubhaloVmaxRad_0D'],  s=3, marker='.', 
                  cmap='Spectral', alpha=0.7, vmin=0.005, vmax=0.15)#, label=label)

ax1.set_xlim([0.0, 0.05])
# ax1.set_xticks([8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0])
ax1.set_ylim([0.0,0.05])
ax1.set_title('Size vs Mass')
ax1.set_xlabel('0D Galaxy Mass')
ax1.set_ylabel('0D Galaxy Size')
# ax1.legend(loc='lower right', shadow=True)


label = ' 0D VmaxRad \n 0D mass-size corr={} \n 0D spin-size corr={}'.format(mass_size_corr_0D, mom_size_corr_0D )
im2 = ax2.scatter(df_0D_clean['GroupSpin_dmo'], df_0D_clean['SubhaloRstar_0D'], 
#                      s=3, marker='.', alpha=0.7,label= label)
                  c = df_0D_clean.loc[:,'SubhaloVmaxRad_0D'],  s=3, marker='.', 
                  cmap='Spectral', alpha=0.7,label= label, vmin=0.005, vmax=0.15)

ax2.set_xlim([0.0,0.1])
ax2.set_xticks([ 0.02, 0.04, 0.06, 0.08, 0.1])
# ax2.set_ylim([-3.0, 1.1])
ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')
ax2.legend(loc='upper right' , shadow=True)

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
fig.colorbar(im2, cax=cbar_ax)

# plt.savefig("TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_centrals_0D_Mass_Size_AngMom_colorVmaxRad.jpeg", dpi=500)
plt.show()

# %%
plt.hist(df_0D_clean.loc[:,'SubhaloVmaxRad_0D'], bins=200)
plt.show()

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,5))
fig.suptitle('TNG-SIM Central Galaxies v3:0D Size, 0D Mass and Halo Spin  ', fontsize=14, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

im1 = ax1.scatter(df_0D_clean['SubhaloMstar_0D'], df_0D_clean['SubhaloRstar_0D'], 
#                     s=3, marker='.', alpha=0.7) 
                  c = df_0D_clean.loc[:,'SubhaloRgas_0D'],  s=3, marker='.', 
                  cmap='Spectral', alpha=0.7, vmin=0.1, vmax=0.5)#, label=label)

ax1.set_xlim([0.0, 0.05])
# ax1.set_xticks([8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0])
ax1.set_ylim([0.0,0.05])
ax1.set_title('Size vs Mass')
ax1.set_xlabel('0D Galaxy Mass')
ax1.set_ylabel('0D Galaxy Size')
# ax1.legend(loc='lower right', shadow=True)


label = ' 0D Rgas \n 0D mass-size corr={} \n 0D spin-size corr={}'.format(mass_size_corr_0D, mom_size_corr_0D )
im2 = ax2.scatter(df_0D_clean['GroupSpin_dmo'], df_0D_clean['SubhaloRstar_0D'], 
#                      s=3, marker='.', alpha=0.7,label= label)
                  c = df_0D_clean.loc[:,'SubhaloRgas_0D'],  s=3, marker='.', 
                  cmap='Spectral', alpha=0.7,label= label, vmin=0.1, vmax=0.5)

ax2.set_xlim([0.0,0.1])
ax2.set_xticks([ 0.02, 0.04, 0.06, 0.08, 0.1])
# ax2.set_ylim([-3.0, 1.1])
ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')
ax2.legend(loc='upper right' , shadow=True)

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
fig.colorbar(im2, cax=cbar_ax)

# plt.savefig("TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_centrals_0D_Mass_Size_AngMom_colorRgas.jpeg", dpi=500)
plt.show()

# %%
plt.hist(df_0D_clean.loc[:,'SubhaloRgas_0D'], bins=200)
plt.show()

# %%
plt.hist(df_0D_clean.loc[:,'SubhaloRstar_0D'], bins=200)
plt.show()

# %%
df_0D[df_0D['SubhaloRstar_0D']>=0.03]
# Out:
#         SubhaloBHMass  SubhaloBHMdot  SubhaloGasMetallicity   SubhaloMass  \
# 0        9.956542e+09       0.000398               0.007718  3.903116e+14
# 17185    7.911793e+09       0.000097               0.004368  3.901083e+14
# 31342    1.190802e+10       0.000372               0.005708  3.297064e+14
# 60731    4.747481e+09       0.000153               0.004736  2.039766e+14
# 96500    6.298731e+09       0.000180               0.006628  1.747119e+14
# ...               ...            ...                    ...           ...
# 901833   0.000000e+00       0.000000               0.000000  1.049166e+10
# 916946   0.000000e+00       0.000000               0.000000  6.872328e+09
# 925463   0.000000e+00       0.000000               0.000000  6.986945e+09
# 931184   0.000000e+00       0.000000               0.000000  5.913835e+09
# 942269   0.000000e+00       0.000000               0.000000  5.635641e+09
#
#         SubhaloSFRinRad  SubhaloStarMetallicity  SubhaloVelDisp  SubhaloVmax  \
# 0              0.195825                0.028622      603.875061   999.385132
# 17185          1.657662                0.020940      594.971252   959.352661
# 31342          1.530534                0.022085      567.029297   983.835571
# 60731          0.000000                0.024737      490.098572   843.690063
# 96500          1.791764                0.023215      477.033081   829.236206
# ...                 ...                     ...             ...          ...
# 901833         0.000000                0.006870       29.541777    57.073399
# 916946         0.000000                0.011401       27.836445    59.340427
# 925463         0.000000                0.007651       27.146893    54.506321
# 931184         0.000000                0.010493       28.520468    59.081474
# 942269         0.000000                0.009866       22.921013    50.962437
#
#         SubhaloVmaxRad  SubhaloRgas  SubhaloRstar   SubhaloMgas  SubhaloMstar  \
# 0           465.664864   891.066223     67.312584  1.236131e+13  3.143714e+12
# 17185      1364.142938   974.030151    125.480888  4.078112e+13  2.074321e+12
# 31342       880.071813   763.659424     82.916382  2.839754e+13  2.539053e+12
# 60731       575.493422   699.954895     47.417694  1.106990e+13  1.199924e+12
# 96500       418.308735   605.067444     50.140224  7.330423e+12  1.580071e+12
# ...                ...          ...           ...           ...           ...
# 901833        4.682093     0.000000      3.610430  0.000000e+00  2.633523e+08
# 916946        2.572634     0.000000      3.105893  0.000000e+00  3.391862e+08
# 925463        3.933093     0.000000      4.197745  0.000000e+00  2.745615e+08
# 931184        2.980457     0.000000      2.867347  0.000000e+00  3.214156e+08
# 942269        3.033161     0.000000      3.620246  0.000000e+00  2.512916e+08
#
#         GroupNsubs   GroupBHMass  Group_M_Crit200  Group_M_TopHat200  \
# 0            17185  3.604464e+10     3.625763e+14       4.435949e+14
# 17185        14157  2.687727e+10     3.667457e+14       4.869390e+14
# 31342        10240  2.595396e+10     3.247846e+14       3.869459e+14
# 60731         8776  1.948211e+10     1.955006e+14       2.321074e+14
# 96500         6183  1.325898e+10     1.569510e+14       1.887050e+14
# ...            ...           ...              ...                ...
# 901833           1  0.000000e+00     1.089233e+10       1.144587e+10
# 916946           1  0.000000e+00     6.951248e+09       7.252348e+09
# 925463           1  0.000000e+00     7.657354e+09       8.092290e+09
# 931184           1  0.000000e+00     6.436872e+09       7.048120e+09
# 942269           1  0.000000e+00     5.720889e+09       6.255539e+09
#
#         Group_R_Crit200  Group_R_TopHat200    SubhaloMHI    SubhaloMH2  \
# 0           1465.437988        1959.448853  1.153075e+10  1.105946e+10
# 17185       1471.055298        2021.319336  7.938982e+09  9.032034e+09
# 31342       1412.607422        1872.237793  4.318117e+09  4.893413e+09
# 60731       1192.737549        1578.948242  6.801115e+09  5.830522e+09
# 96500       1108.538818        1473.716797  8.865095e+09  8.187513e+09
# ...                 ...                ...           ...           ...
# 901833        45.554394          57.903389  0.000000e+00  0.000000e+00
# 916946        39.220924          49.733822  0.000000e+00  0.000000e+00
# 925463        40.508286          51.582172  0.000000e+00  0.000000e+00
# 931184        38.229462          49.259880  0.000000e+00  0.000000e+00
# 942269        36.756042          47.341087  0.000000e+00  0.000000e+00
#
#         SubhaloMass_dmo  SubhaloVelDisp_dmo  SubhaloVmax_dmo  \
# 0          4.086920e+14          635.132324       981.919495
# 17185      3.872118e+14          625.554626       915.306152
# 31342      3.320254e+14          594.152649       963.913086
# 60731      2.078619e+14          514.494202       838.583557
# 96500      1.784437e+14          491.891449       818.701721
# ...                 ...                 ...              ...
# 901833     1.737694e+10           35.115726        67.265320
# 916946     1.548499e+10           34.802910        70.209656
# 925463     1.533159e+10           33.283447        64.543488
# 931184     1.307319e+10           35.896076        70.614082
# 942269     1.430040e+10           34.503525        66.300270
#
#         SubhaloVmaxRad_dmo  GroupNsubs_dmo  Group_M_Crit200_dmo  \
# 0               519.949219         24681.0         3.505198e+14
# 17185          1388.533679         19381.0         3.363435e+14
# 31342           819.257823         14812.0         3.134071e+14
# 60731           574.677424         12549.0         1.924220e+14
# 96500           413.947235          8898.0         1.533361e+14
# ...                    ...             ...                  ...
# 901833            7.284349           946.0         1.731329e+13
# 916946            4.856606             2.0         1.551056e+10
# 925463            5.553132          3108.0         6.536413e+13
# 931184            4.757021           439.0         1.541116e+13
# 942269            6.030053          2996.0         5.444613e+13
#
#         Group_M_TopHat200_dmo  Group_R_Crit200_dmo  Group_R_TopHat200_dmo  \
# 0                4.375438e+14          1449.026489            1950.562622
# 17185            4.621193e+14          1429.226929            1986.413452
# 31342            3.839523e+14          1395.976807            1867.351074
# 60731            2.302046e+14          1186.489868            1574.687256
# 96500            1.843349e+14          1099.976318            1462.228271
# ...                       ...                  ...                    ...
# 901833           2.131539e+13           531.648926             712.381348
# 916946           1.663550e+10            51.250938              65.586479
# 925463           8.028313e+13           827.841431            1108.349976
# 931184           1.769942e+13           511.432312             669.586731
# 942269           6.837425e+13           778.910278            1050.589600
#
#         Group_V_TopHat200  Group_V_Crit200  GroupSpin  Group_V_TopHat200_dmo  \
# 0              986.644165      1031.454834   0.015910             982.121096
# 17185         1017.780334      1035.385864   0.013266            1000.176016
# 31342          942.711609       994.308533   0.034117             940.285789
# 60731          795.050659       839.529175   0.026669             792.855537
# 96500          742.025635       780.262634   0.015667             736.258598
# ...                   ...              ...        ...                    ...
# 901833          29.154572        32.064873   0.003929             358.694438
# 916946          25.040766        27.606205   0.006042              33.025167
# 925463          25.972881        28.510292   0.008419             558.094728
# 931184          24.804142        26.907452   0.004932             337.140071
# 942269          23.836773        25.870310   0.009180             529.010112
#
#         Group_V_Crit200_dmo  GroupSpin_dmo  SubhaloRstar_0D  SubhaloRgas_0D  \
# 0               1019.887621       0.016995         0.034353        0.454753
# 17185           1005.947150       0.012785         0.062079        0.481878
# 31342            982.538398       0.032441         0.044287        0.407886
# 60731            835.082831       0.023233         0.030031        0.443305
# 96500            774.220561       0.015179         0.034023        0.410572
# ...                     ...            ...              ...             ...
# 901833           374.206745       0.000060         0.062353        0.000000
# 916946            36.074229       0.009550         0.062450        0.000000
# 925463           582.680394       0.000036         0.081380        0.000000
# 931184           359.963013       0.000077         0.058209        0.000000
# 942269           548.244187       0.000023         0.076472        0.000000
#
#         SubhaloVmaxRad_0D  SubhaloVmaxRad_dmo_0D  SubhaloVmax_0D  \
# 0                0.237651               0.265355        1.012913
# 17185            0.674877               0.686944        0.942593
# 31342            0.470064               0.437582        1.043623
# 60731            0.364479               0.363962        1.061178
# 96500            0.283846               0.280887        1.117530
# ...                   ...                    ...             ...
# 901833           0.080860               0.125802        1.957614
# 916946           0.051728               0.097652        2.369753
# 925463           0.076249               0.107656        2.098586
# 931184           0.060505               0.096570        2.381920
# 942269           0.064070               0.127375        2.137975
#
#         SubhaloVmax_dmo_0D  SubhaloVelDisp_0D  SubhaloVelDisp_dmo_0D  \
# 0                 0.995211           0.612050               0.643730
# 17185             0.899316           0.584577               0.614626
# 31342             1.022490           0.601488               0.630259
# 60731             1.054755           0.616437               0.647121
# 96500             1.103333           0.642880               0.662904
# ...                    ...                ...                    ...
# 901833            2.307196           1.013281               1.204467
# 916946            2.803814           1.111645               1.389850
# 925463            2.485034           1.045201               1.281469
# 931184            2.846867           1.149827               1.447181
# 942269            2.781428           0.961582               1.447491
#
#         SubhaloMgas_0D  SubhaloMstar_0D  SubhaloBHMass_0D  GroupBHMass_0D  \
# 0             0.027866         0.007087          0.000022        0.000081
# 17185         0.083750         0.004260          0.000016        0.000055
# 31342         0.073389         0.006562          0.000031        0.000067
# 60731         0.047693         0.005170          0.000020        0.000084
# 96500         0.038846         0.008373          0.000033        0.000070
# ...                ...              ...               ...             ...
# 901833        0.000000         0.023008          0.000000        0.000000
# 916946        0.000000         0.046769          0.000000        0.000000
# 925463        0.000000         0.033929          0.000000        0.000000
# 931184        0.000000         0.045603          0.000000        0.000000
# 942269        0.000000         0.040171          0.000000        0.000000
#
#         SubhaloBHMdot_0D  SubhaloMHI_0D  SubhaloMH2_0D  Group_R_TopHat200_0D  \
# 0           8.972381e-19       0.000026       0.000025                   1.0
# 17185       1.997091e-19       0.000016       0.000019                   1.0
# 31342       9.622102e-19       0.000011       0.000013                   1.0
# 60731       6.575413e-19       0.000029       0.000025                   1.0
# 96500       9.548997e-19       0.000047       0.000043                   1.0
# ...                  ...            ...            ...                   ...
# 901833      0.000000e+00       0.000000       0.000000                   1.0
# 916946      0.000000e+00       0.000000       0.000000                   1.0
# 925463      0.000000e+00       0.000000       0.000000                   1.0
# 931184      0.000000e+00       0.000000       0.000000                   1.0
# 942269      0.000000e+00       0.000000       0.000000                   1.0
#
#         Group_R_TopHat200_dmo_0D  Group_R_Crit200_0D  Group_R_Crit200_dmo_0D  \
# 0                       0.995465            0.747883                0.739507
# 17185                   0.982731            0.727770                0.707076
# 31342                   0.997390            0.754502                0.745619
# 60731                   0.997301            0.755400                0.751443
# 96500                   0.992204            0.752206                0.746396
# ...                          ...                 ...                     ...
# 901833                 12.302930            0.786731                9.181655
# 916946                  1.318750            0.788617                1.030505
# 925463                 21.487074            0.785316               16.048983
# 931184                 13.592943            0.776077               10.382330
# 942269                 22.191920            0.776409               16.453156
#
#         Group_M_TopHat200_0D  Group_M_TopHat200_dmo_0D  Group_M_Crit200_0D  \
# 0                        1.0                  0.986359            0.817359
# 17185                    1.0                  0.949029            0.753166
# 31342                    1.0                  0.992264            0.839354
# 60731                    1.0                  0.991802            0.842285
# 96500                    1.0                  0.976841            0.831727
# ...                      ...                       ...                 ...
# 901833                   1.0               1862.277939            0.951639
# 916946                   1.0                  2.293809            0.958482
# 925463                   1.0               9920.941479            0.946253
# 931184                   1.0               2511.226312            0.913275
# 942269                   1.0              10930.194084            0.914532
#
#         Group_M_Crit200_dmo_0D  SubhaloMass_0D  SubhaloMass_dmo_0D  \
# 0                     0.790180        0.879883            0.921318
# 17185                 0.690730        0.801144            0.795196
# 31342                 0.809951        0.852074            0.858067
# 60731                 0.829021        0.878802            0.895542
# 96500                 0.812570        0.925847            0.945623
# ...                        ...             ...                 ...
# 901833             1512.623483        0.916632            1.518184
# 916946                2.138695        0.947600            2.135170
# 925463             8077.335087        0.863408            1.894593
# 931184             2186.563958        0.839066            1.854847
# 942269             8703.668399        0.900904            2.286037
#
#         Group_V_TopHat200_0D  Group_V_TopHat200_dmo_0D  Group_V_Crit200_0D  \
# 0                        1.0                  0.995416            1.045417
# 17185                    1.0                  0.982703            1.017298
# 31342                    1.0                  0.997427            1.054732
# 60731                    1.0                  0.997239            1.055944
# 96500                    1.0                  0.992228            1.051531
# ...                      ...                       ...                 ...
# 901833                   1.0                 12.303197            1.099823
# 916946                   1.0                  1.318856            1.102450
# 925463                   1.0                 21.487594            1.097695
# 931184                   1.0                 13.592088            1.084797
# 942269                   1.0                 22.193026            1.085311
#
#         Group_V_Crit200_dmo_0D
# 0                     1.033693
# 17185                 0.988374
# 31342                 1.042247
# 60731                 1.050352
# 96500                 1.043388
# ...                        ...
# 901833               12.835268
# 916946                1.440620
# 925463               22.434184
# 931184               14.512214
# 942269               22.999933
#
# [2348 rows x 65 columns]

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,5))
fig.suptitle('TNG-SIM Central Galaxies v3:0D Size, 0D Mass and Halo Spin  ', fontsize=14, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

im1 = ax1.scatter(df_0D_clean['SubhaloMstar_0D'], df_0D_clean['SubhaloRstar_0D'], 
#                     s=3, marker='.', alpha=0.7) 
                  c = df_0D_clean.loc[:,'SubhaloMHI_0D'],  s=3, marker='.', 
                  cmap='Spectral', alpha=0.7, vmin=0.0, vmax=0.025)#, label=label)

ax1.set_xlim([0.0, 0.05])
# ax1.set_xticks([8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0])
ax1.set_ylim([0.0,0.05])
ax1.set_title('Size vs Mass')
ax1.set_xlabel('0D Galaxy Mass')
ax1.set_ylabel('0D Galaxy Size')
# ax1.legend(loc='lower right', shadow=True)


label = ' 0D MHI \n 0D mass-size corr={} \n 0D spin-size corr={}'.format(mass_size_corr_0D, mom_size_corr_0D )
im2 = ax2.scatter(df_0D_clean['GroupSpin_dmo'], df_0D_clean['SubhaloRstar_0D'], 
#                      s=3, marker='.', alpha=0.7,label= label)
                  c = df_0D_clean.loc[:,'SubhaloMHI_0D'],  s=3, marker='.', 
                  cmap='Spectral', alpha=0.7,label= label, vmin=0.0, vmax=0.025)

ax2.set_xlim([0.0,0.1])
ax2.set_xticks([ 0.02, 0.04, 0.06, 0.08, 0.1])
# ax2.set_ylim([-3.0, 1.1])
ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')
ax2.legend(loc='upper right' , shadow=True)

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
fig.colorbar(im2, cax=cbar_ax)

# plt.savefig("TNG-SIM_images/v3_initial_analysis/v3_TNG-SIM_centrals_0D_Mass_Size_AngMom_colorMHI.jpeg", dpi=500)
plt.show()

# %%
plt.hist(df_0D_clean.loc[:,'SubhaloMHI_0D'], bins=200, range=(0.0, 0.08))
plt.show()

# %% [markdown]
# df[(df.loc[:, 'SubhaloLogMstar']>8) & (df.loc[:, 'SubhaloFlag'] == True)]
